# %% [markdown]
# # Pandas

# %% [markdown]
# Pandas là một thư viện được viết cho ngôn ngữ lập trình Python được sử dụng để thao tác với dữ liệu và phân tích dữ liệu. Thư viện cung cấp cho chúng ta các cấu trúc dữ liệu và các phép toán phục vụ thao tác với các bảng.

# %% [markdown]
# Tính năng của thư viện Pandas
# - Tạo Series
# - Tạo bảng DataFrame
# - Đọc ghi các biểu bảng
# - Các thao tác phân tích dữ liệu
# - Các thao tác lọc và làm sạch dữ liệu
# - Vẽ biểu bảng cho dữ liệu

# %% [markdown]
# # Cài đặt và khai báo thư viện

# %%
# !pip install pandas # Cài đặt pandas
# Out:
# ERROR: Invalid requirement: '#'
#
# [notice] A new release of pip is available: 23.1.1 -> 23.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Series

# %% [markdown]
# Series là kiểu dữ một trong hai kiểu dữ liệu cơ bản của Pandas. Series là kiểu dữ liệu mảng một chiều

# %%
arr = [1,2,3,4,5]
s = pd.Series(arr)
s
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %% [markdown]
# Series có nhiều thao tác giống với ndarray của Numpy. Tuy nhiên Series chỉ cho phép mảng một chiều

# %%
s[0]=2
s
# Out:
# 0    2
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
print(s.sum())
# Out:
# 16

# %%
print(s.cumsum())
# Out:
# 0     2
# 1     4
# 2     7
# 3    11
# 4    16
# dtype: int64

# %%
print(s.mean())
# Out:
# 3.2

# %%
print(s.argmax())
# Out:
# 4

# %% [markdown]
# Điều khác biệt lớn nhất giữa Series và ndarray có lẽ là
#   - Series chỉ cho phép sử dụng mảng một chiều
#   - Series cho phép chỉ số được quyền là chữ và truy cập theo tên của chỉ số

# %%
arr = [[1,2],[3,4],[5,6]]
s = pd.Series(arr)
s
# Out:
# 0    [1, 2]
# 1    [3, 4]
# 2    [5, 6]
# dtype: object

# %%
s[0]
# Out:
# [1, 2]

# %%
data = {'An':9,
        'Bình':8,
        'Cường':8,
        'Diễm':9}
s = pd.Series(data)
s
# Out:
# An       9
# Bình     8
# Cường    8
# Diễm     9
# dtype: int64

# %%
s['An']
# Out:
# 9

# %% [markdown]
# - Tạo Series s
# - Sửa Điểm của Bình = 9
# - Thêm Điểm của Đạt = 7

# %%
s = pd.Series(['two', 'two', 'two', 'four', 'four', 'two', 'four', 'four', 'four',
              'two', 'two', 'four', 'two', 'four', 'four', 'four', 'two', 'four',
              'two', 'two', 'four', 'two', 'two', 'two', 'four', 'four', 'four',
              np.nan, 'four', 'two', 'two', 'two', 'two', 'two', 'two', 'four',
              'four', 'two', 'two', 'four', 'four', 'four', 'two', 'four', 'two',
              'four', 'two', 'four', 'four', 'two', 'two', 'two', 'two', 'four',
              'four', 'two', 'two', 'two', 'two', 'two', 'four', 'two', 'four',
              np.nan, 'four', 'four', 'four', 'four', 'four', 'two', 'four', 'four',
              'two', 'four', 'two', 'two', 'two', 'two', 'two', 'two', 'two',
              'two', 'two', 'two', 'two', 'four', 'four', 'four', 'four', 'two',
              'two', 'two', 'four', 'four', 'two', 'two', 'four', 'four', 'two',
              'four', 'four', 'four', 'four', 'four', 'two', 'two', 'two',
              'four', 'four', 'four', 'four', 'four', 'four', 'four', 'four',
              'four', 'four', 'four', 'two', 'two', 'four', 'four', 'four',
              'four', 'two', 'two', 'two', 'two', 'two', 'two', 'four', 'two',
              'two', 'four', 'two', 'four', 'two', 'four', 'two', 'two', 'two',
              'four', 'four', 'four', 'four', 'four', 'four', 'four', 'four',
              'four', 'two', 'two', 'four', 'four', 'four', 'four', 'four',
              'four', 'four', 'four', 'four', 'four', 'four', 'two', 'two',
              'two', 'two', 'two', 'two', 'two', 'two', 'two', 'two', 'four',
              'four', 'four', 'four', 'four', 'two', 'two', 'four', 'four',
              'two', 'two', 'four', 'four', 'four', 'four', 'four', 'two', 'two',
              'four', 'four', 'four', 'four', 'four', 'four', 'four', 'four',
              'four', 'four', 'four', 'four', 'four', 'four'])

# %%
s.value_counts()
# Out:
# four    114
# two      89
# Name: count, dtype: int64

# %%
s.value_counts(dropna=False)
# Out:
# four    114
# two      89
# NaN       2
# Name: count, dtype: int64

# %%
s.unique()
# Out:
# array(['two', 'four', nan], dtype=object)

# %% [markdown]
# # DataFrame

# %% [markdown]
# ## Khởi tạo

# %% [markdown]
# ### Tạo DataFrame từ list

# %%
data = [['An',9],['Bình',8],['Cường',8],['Diễm',10]]
df = pd.DataFrame(data,columns =['Tên','Điểm'])
df
# Out:
#      Tên  Điểm
# 0     An     9
# 1   Bình     8
# 2  Cường     8
# 3   Diễm    10

# %% [markdown]
# ### Tạo DataFrame từ dict

# %%
data = {'Tên':['An','Bình','Cường','Diễm'],'Điểm':[9,8,8,10]}
df = pd.DataFrame(data)
df
# Out:
#      Tên  Điểm
# 0     An     9
# 1   Bình     8
# 2  Cường     8
# 3   Diễm    10

# %% [markdown]
# Tạo dữ liệu sau sử dụng cả hai cách:
#
# ||date|volumes_max|volumes|temperature|
# |-|-:|-:|-:|-:|
# |0|	01/01/2022|	120.0	|120.0|	22.0|
# |1|	02/01/2022|	123.0	|130.0|	23.0|
# |2|	03/01/2022|	102.0	|102.0|	21.0
# |3|	04/01/2022|	NaN	  |NaN  |	36.0
# |4|	05/01/2022|	111.0	|111.0|	NaN
# |5|	06/01/2022|	NaN	  |NaN	|31.0
# |6|	06/01/2022|	124.0	|124.0|	25.0

# %% [markdown]
# ``` python
# NaN = None
# ```

# %% [markdown]
# ### Lấy DataFrame từ file

# %%
df = pd.read_csv('Salary_Data.csv')
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 df = pd.read_csv('Salary_Data.csv')
#       2 df.head()
#
# File c:\Users\nguye\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\parsers\readers.py:912, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     899 kwds_defaults = _refine_defaults_read(
#     900     dialect,
#     901     delimiter,
#    (...)
#     908     dtype_backend=dtype_backend,
#     909 )
#     910 kwds.update(kwds_defaults)
# --> 912 return _read(filepath_or_buffer, kwds)
#
# File c:\Users\nguye\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\parsers\readers.py:577, in _read(filepath_or_buffer, kwds)
#     574 _validate_names(kwds.get("names", None))
#     576 # Create the parser.
# --> 577 parser = TextFileReader(filepath_or_buffer, **kwds)
#     579 if chunksize or iterator:
#     580     return parser
#
# File c:\Users\nguye\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\parsers\readers.py:1407, in TextFileReader.__init__(self, f, engine, **kwds)
#    1404     self.options["has_index_names"] = kwds["has_index_names"]
#    1406 self.handles: IOHandles | None = None
# -> 1407 self._engine = self._make_engine(f, self.engine)
#
# File c:\Users\nguye\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\parsers\readers.py:1661, in TextFileReader._make_engine(self, f, engine)
#    1659     if "b" not in mode:
#    1660         mode += "b"
# -> 1661 self.handles = get_handle(
#    1662     f,
#    1663     mode,
#    1664     encoding=self.options.get("encoding", None),
#    1665     compression=self.options.get("compression", None),
#    1666     memory_map=self.options.get("memory_map", False),
#    1667     is_text=is_text,
#    1668     errors=self.options.get("encoding_errors", "strict"),
#    1669     storage_options=self.options.get("storage_options", None),
#    1670 )
#    1671 assert self.handles is not None
#    1672 f = self.handles.handle
#
# File c:\Users\nguye\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\common.py:859, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     854 elif isinstance(handle, str):
#     855     # Check whether the filename is to be opened in binary mode.
#     856     # Binary mode does not support 'encoding' and 'newline'.
#     857     if ioargs.encoding and "b" not in ioargs.mode:
#     858         # Encoding
# --> 859         handle = open(
#     860             handle,
#     861             ioargs.mode,
#     862             encoding=ioargs.encoding,
#     863             errors=errors,
#     864             newline="",
#     865         )
#     866     else:
#     867         # Binary mode
#     868         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Salary_Data.csv'

# %%
df = pd.read_csv("https://raw.githubusercontent.com/pandas-dev/pandas/main/doc/data/air_quality_no2.csv")
df.head()
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# File c:\Users\nguye\AppData\Local\Programs\Python\Python310\lib\urllib\request.py:1348, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1347 try:
# -> 1348     h.request(req.get_method(), req.selector, req.data, headers,
#    1349               encode_chunked=req.has_header('Transfer-encoding'))
#    1350 except OSError as err: # timeout error
#
# File c:\Users\nguye\AppData\Local\Programs\Python\Python310\lib\http\client.py:1283, in HTTPConnection.request(self, method, url, body, headers, encode_chunked)
#    1282 """Send a complete request to the server."""
# -> 1283 self._send_request(method, url, body, headers, encode_chunked)
#
# File c:\Users\nguye\AppData\Local\Programs\Python\Python310\lib\http\client.py:1329, in HTTPConnection._send_request(self, method, url, body, headers, encode_chunked)
#    1328     body = _encode(body, 'body')
# -> 1329 self.endheaders(body, encode_chunked=encode_chunked)
#
# File c:\Users\nguye\AppData\Local\Programs\Python\Python310\lib\http\client.py:1278, in HTTPConnection.endheaders(self, message_body, encode_chunked)
#    1277     raise CannotSendHeader()
# -> 1278 self._send_output(message_body, encode_chunked=encode_chunked)
#
# File c:\Users\nguye\AppData\Local\Programs\Python\Python310\lib\http\client.py:1038, in HTTPConnection._send_output(self, message_body, encode_chunked)
#    1037 del self._buffer[:]
# -> 1038 self.send(msg)
#    1040 if message_body is not None:
#    1041
#    1042     # create a consistent interface to message_body
#
# File c:\Users\nguye\AppData\Local\Programs\Python\Python310\lib\http\client.py:976, in HTTPConnection.send(self, data)
#     975 if self.auto_open:
# --> 976     self.connect()
#     977 else:
#
# File c:\Users\nguye\AppData\Local\Programs\Python\Python310\lib\http\client.py:1448, in HTTPSConnection.connect(self)
#    1446 "Connect to a host on a given (SSL) port."
# -> 1448 super().connect()
#    1450 if self._tunnel_host:
#
# File c:\Users\nguye\AppData\Local\Programs\Python\Python310\lib\http\client.py:942, in HTTPConnection.connect(self)
#     941 sys.audit("http.client.connect", self, self.host, self.port)
# --> 942 self.sock = self._create_connection(
#     943     (self.host,self.port), self.timeout, self.source_address)
#     944 # Might fail in OSs that don't implement TCP_NODELAY
#
# File c:\Users\nguye\AppData\Local\Programs\Python\Python310\lib\socket.py:824, in create_connection(address, timeout, source_address)
#     823 err = None
# --> 824 for res in getaddrinfo(host, port, 0, SOCK_STREAM):
#     825     af, socktype, proto, canonname, sa = res
#
# File c:\Users\nguye\AppData\Local\Programs\Python\Python310\lib\socket.py:955, in getaddrinfo(host, port, family, type, proto, flags)
#     954 addrlist = []
# --> 955 for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     956     af, socktype, proto, canonname, sa = res
#
# gaierror: [Errno 11001] getaddrinfo failed
#
# During handling of the above exception, another exception occurred:
#
# URLError                                  Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 df = pd.read_csv("https://raw.githubusercontent.com/pandas-dev/pandas/main/doc/data/air_quality_no2.csv")
#       2 df.head()
#
# File c:\Users\nguye\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\parsers\readers.py:912, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     899 kwds_defaults = _refine_defaults_read(
#     900     dialect,
#     901     delimiter,
#    (...)
#     908     dtype_backend=dtype_backend,
#     909 )
#     910 kwds.update(kwds_defaults)
# --> 912 return _read(filepath_or_buffer, kwds)
#
# File c:\Users\nguye\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\parsers\readers.py:577, in _read(filepath_or_buffer, kwds)
#     574 _validate_names(kwds.get("names", None))
#     576 # Create the parser.
# --> 577 parser = TextFileReader(filepath_or_buffer, **kwds)
#     579 if chunksize or iterator:
#     580     return parser
#
# File c:\Users\nguye\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\parsers\readers.py:1407, in TextFileReader.__init__(self, f, engine, **kwds)
#    1404     self.options["has_index_names"] = kwds["has_index_names"]
#    1406 self.handles: IOHandles | None = None
# -> 1407 self._engine = self._make_engine(f, self.engine)
#
# File c:\Users\nguye\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\parsers\readers.py:1661, in TextFileReader._make_engine(self, f, engine)
#    1659     if "b" not in mode:
#    1660         mode += "b"
# -> 1661 self.handles = get_handle(
#    1662     f,
#    1663     mode,
#    1664     encoding=self.options.get("encoding", None),
#    1665     compression=self.options.get("compression", None),
#    1666     memory_map=self.options.get("memory_map", False),
#    1667     is_text=is_text,
#    1668     errors=self.options.get("encoding_errors", "strict"),
#    1669     storage_options=self.options.get("storage_options", None),
#    1670 )
#    1671 assert self.handles is not None
#    1672 f = self.handles.handle
#
# File c:\Users\nguye\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\common.py:716, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     713     codecs.lookup_error(errors)
#     715 # open URLs
# --> 716 ioargs = _get_filepath_or_buffer(
#     717     path_or_buf,
#     718     encoding=encoding,
#     719     compression=compression,
#     720     mode=mode,
#     721     storage_options=storage_options,
#     722 )
#     724 handle = ioargs.filepath_or_buffer
#     725 handles: list[BaseBuffer]
#
# File c:\Users\nguye\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\common.py:368, in _get_filepath_or_buffer(filepath_or_buffer, encoding, compression, mode, storage_options)
#     366 # assuming storage_options is to be interpreted as headers
#     367 req_info = urllib.request.Request(filepath_or_buffer, headers=storage_options)
# --> 368 with urlopen(req_info) as req:
#     369     content_encoding = req.headers.get("Content-Encoding", None)
#     370     if content_encoding == "gzip":
#     371         # Override compression based on Content-Encoding header
#
# File c:\Users\nguye\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\common.py:270, in urlopen(*args, **kwargs)
#     264 """
#     265 Lazy-import wrapper for stdlib urlopen, as that imports a big chunk of
#     266 the stdlib.
#     267 """
#     268 import urllib.request
# --> 270 return urllib.request.urlopen(*args, **kwargs)
#
# File c:\Users\nguye\AppData\Local\Programs\Python\Python310\lib\urllib\request.py:216, in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     214 else:
#     215     opener = _opener
# --> 216 return opener.open(url, data, timeout)
#
# File c:\Users\nguye\AppData\Local\Programs\Python\Python310\lib\urllib\request.py:519, in OpenerDirector.open(self, fullurl, data, timeout)
#     516     req = meth(req)
#     518 sys.audit('urllib.Request', req.full_url, req.data, req.headers, req.get_method())
# --> 519 response = self._open(req, data)
#     521 # post-process response
#     522 meth_name = protocol+"_response"
#
# File c:\Users\nguye\AppData\Local\Programs\Python\Python310\lib\urllib\request.py:536, in OpenerDirector._open(self, req, data)
#     533     return result
#     535 protocol = req.type
# --> 536 result = self._call_chain(self.handle_open, protocol, protocol +
#     537                           '_open', req)
#     538 if result:
#     539     return result
#
# File c:\Users\nguye\AppData\Local\Programs\Python\Python310\lib\urllib\request.py:496, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     494 for handler in handlers:
#     495     func = getattr(handler, meth_name)
# --> 496     result = func(*args)
#     497     if result is not None:
#     498         return result
#
# File c:\Users\nguye\AppData\Local\Programs\Python\Python310\lib\urllib\request.py:1391, in HTTPSHandler.https_open(self, req)
#    1390 def https_open(self, req):
# -> 1391     return self.do_open(http.client.HTTPSConnection, req,
#    1392         context=self._context, check_hostname=self._check_hostname)
#
# File c:\Users\nguye\AppData\Local\Programs\Python\Python310\lib\urllib\request.py:1351, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1348         h.request(req.get_method(), req.selector, req.data, headers,
#    1349                   encode_chunked=req.has_header('Transfer-encoding'))
#    1350     except OSError as err: # timeout error
# -> 1351         raise URLError(err)
#    1352     r = h.getresponse()
#    1353 except:
#
# URLError: <urlopen error [Errno 11001] getaddrinfo failed>

# %% [markdown]
# ## Thuộc tính và dữ liệu cơ bản

# %% [markdown]
# - DataFrame.index : Chỉ số dòng của DataFrame
#
# - DataFrame.columns : Chỉ số cột của DataFrame
#
# - DataFrame.dtypes : Kiểu dữ liệu của DataFrame
#
# - DataFrame.info : In ra bản tóm tắt về DataFrame
#
# - DataFrame.select_dtypes([include, exclude]) : Trả về một bảng dữ liệu con dựa trên kiểu dữ liệu
#
# - DataFrame.values : Trả về mảng NumPy dữ liệu DataFrame
#
# - DataFrame.axes : Trả về các trục (axis/axes) của DataFrame
#
# - DataFrame.ndim : Trả về số chiểu của dữ liệu/ số trục
#
# - DataFrame.size : Trả về số lượng phần tử
#
# - DataFrame.shape : Trả về một tuple thể hiện hình dạng của DataFrame
#
# - DataFrame.memory_usage(index, deep) : Trả về bộ nhớ sử dụng cho mỗi cột đơn vị byte
#
# - DataFrame.empty : Xác định xem DataFrame có rỗng không
#
# - DataFrame.describe(): Mô tả dữ liệu, thống kê dữ liệu

# %%
data = {'date' : pd.to_datetime(['01/01/2022','02/01/2022','03/01/2022','04/01/2022','05/01/2022','06/01/2022','06/01/2022'],format='%d/%m/%Y'),
        'volumes_max' : [120.0, 123.0, 102.0, None, 111.0, None, 124.0],
        'volumes': [120.0, 130.0, 102.0, None, 111.0,None , 124.0],
        'temperature' : [22.0, 23.0, 21.0, 36.0, None, 31.0, 25.0]}
df = pd.DataFrame(data)
df
# Out:
#         date  volumes_max  volumes  temperature
# 0 2022-01-01        120.0    120.0         22.0
# 1 2022-01-02        123.0    130.0         23.0
# 2 2022-01-03        102.0    102.0         21.0
# 3 2022-01-04          NaN      NaN         36.0
# 4 2022-01-05        111.0    111.0          NaN
# 5 2022-01-06          NaN      NaN         31.0
# 6 2022-01-06        124.0    124.0         25.0

# %%
df.index # Có thể sử dụng để thay đổi chỉ số dòng
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
df.index = ['Thứ 2','Thứ 3','Thứ 4','Thứ 5','Thứ 6','Thứ 7','Chủ nhật']
df
# Out:
#                date  volumes_max  volumes  temperature
# Thứ 2    2022-01-01        120.0    120.0         22.0
# Thứ 3    2022-01-02        123.0    130.0         23.0
# Thứ 4    2022-01-03        102.0    102.0         21.0
# Thứ 5    2022-01-04          NaN      NaN         36.0
# Thứ 6    2022-01-05        111.0    111.0          NaN
# Thứ 7    2022-01-06          NaN      NaN         31.0
# Chủ nhật 2022-01-06        124.0    124.0         25.0

# %%
for i in df.index:
  print(i)
# Out:
# Thứ 2
# Thứ 3
# Thứ 4
# Thứ 5
# Thứ 6
# Thứ 7
# Chủ nhật

# %%
df.columns # Có thể sử dụng để đổi tên cột
# Out:
# Index(['date', 'volumes_max', 'volumes', 'temperature'], dtype='object')

# %%
df.columns = ['Date', 'Volumes_max', 'Volumes', 'Temperature']
df
# Out:
#                Date  Volumes_max  Volumes  Temperature
# Thứ 2    2022-01-01        120.0    120.0         22.0
# Thứ 3    2022-01-02        123.0    130.0         23.0
# Thứ 4    2022-01-03        102.0    102.0         21.0
# Thứ 5    2022-01-04          NaN      NaN         36.0
# Thứ 6    2022-01-05        111.0    111.0          NaN
# Thứ 7    2022-01-06          NaN      NaN         31.0
# Chủ nhật 2022-01-06        124.0    124.0         25.0

# %%
df.dtypes
# Out:
# Date           datetime64[ns]
# Volumes_max           float64
# Volumes               float64
# Temperature           float64
# dtype: object

# %%
data = {'Tên':['An','Bình','Cường','Diễm'],
        'Ngày sinh' : pd.to_datetime(['01/01/2022',
                                          '01/02/2022',
                                          '01/03/2022',
                                          '01/04/2022'],format='%d/%m/%Y'),
        'Điểm quá trình':[6,7,8,9],
        'Điểm tổng kết':[7.1,5.3,8.8,10]}
df = pd.DataFrame(data)
df
# Out:
#      Tên  Ngày sinh  Điểm quá trình  Điểm tổng kết
# 0     An 2022-01-01               6            7.1
# 1   Bình 2022-02-01               7            5.3
# 2  Cường 2022-03-01               8            8.8
# 3   Diễm 2022-04-01               9           10.0

# %%
df.dtypes
# Out:
# Tên                       object
# Ngày sinh         datetime64[ns]
# Điểm quá trình             int64
# Điểm tổng kết            float64
# dtype: object

# %%
df.select_dtypes(include = ['float','int'])
# Out:
#    Điểm quá trình  Điểm tổng kết
# 0               6            7.1
# 1               7            5.3
# 2               8            8.8
# 3               9           10.0

# %%
df.select_dtypes(exclude = ['object'])
# Out:
#    Ngày sinh  Điểm quá trình  Điểm tổng kết
# 0 2022-01-01               6            7.1
# 1 2022-02-01               7            5.3
# 2 2022-03-01               8            8.8
# 3 2022-04-01               9           10.0

# %%
data = {'date' : pd.to_datetime(['01/01/2022','02/01/2022','03/01/2022','04/01/2022','05/01/2022','06/01/2022','06/01/2022'],format='%d/%m/%Y'),
        'volumes_max' : [120.0, 123.0, 102.0, None, 111.0, None, 124.0],
        'volumes': [120.0, 130.0, 102.0, None, 111.0	,None , 124.0],
        'temperature' : [22.0, 23.0, 21.0, 36.0, None, 31.0, 25.0]}
df = pd.DataFrame(data)
df
# Out:
#         date  volumes_max  volumes  temperature
# 0 2022-01-01        120.0    120.0         22.0
# 1 2022-01-02        123.0    130.0         23.0
# 2 2022-01-03        102.0    102.0         21.0
# 3 2022-01-04          NaN      NaN         36.0
# 4 2022-01-05        111.0    111.0          NaN
# 5 2022-01-06          NaN      NaN         31.0
# 6 2022-01-06        124.0    124.0         25.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         7 non-null      datetime64[ns]
#  1   volumes_max  5 non-null      float64
#  2   volumes      5 non-null      float64
#  3   temperature  6 non-null      float64
# dtypes: datetime64[ns](1), float64(3)
# memory usage: 352.0 bytes

# %%
df.describe()
# Out:
#        volumes_max     volumes  temperature
# count     5.000000    5.000000     6.000000
# mean    116.000000  117.400000    26.333333
# std       9.354143   11.036304     5.921711
# min     102.000000  102.000000    21.000000
# 25%     111.000000  111.000000    22.250000
# 50%     120.000000  120.000000    24.000000
# 75%     123.000000  124.000000    29.500000
# max     124.000000  130.000000    36.000000

# %%
data = [['An','A'],['Bình','B+'],['Cường','B+'],['Diễm',"A+"]]
df2 = pd.DataFrame(data,columns =['Tên','Điểm'])
df2
# Out:
#      Tên Điểm
# 0     An    A
# 1   Bình   B+
# 2  Cường   B+
# 3   Diễm   A+

# %%
df2.describe()
# Out:
#        Tên Điểm
# count    4    4
# unique   4    3
# top     An   B+
# freq     1    2

# %%
data = {'Tên':['An','Bình','Cường','Diễm'],'Điểm':[9,8,8,10]}
df3 = pd.DataFrame(data)
df3
# Out:
#      Tên  Điểm
# 0     An     9
# 1   Bình     8
# 2  Cường     8
# 3   Diễm    10

# %%
df3.describe()
# Out:
#             Điểm
# count   4.000000
# mean    8.750000
# std     0.957427
# min     8.000000
# 25%     8.000000
# 50%     8.500000
# 75%     9.250000
# max    10.000000

# %%
df3.describe(include = 'all')
# Out:
#         Tên       Điểm
# count     4   4.000000
# unique    4        NaN
# top      An        NaN
# freq      1        NaN
# mean    NaN   8.750000
# std     NaN   0.957427
# min     NaN   8.000000
# 25%     NaN   8.000000
# 50%     NaN   8.500000
# 75%     NaN   9.250000
# max     NaN  10.000000

# %%
df.values
# Out:
# array([[Timestamp('2022-01-01 00:00:00'), 120.0, 120.0, 22.0],
#        [Timestamp('2022-01-02 00:00:00'), 123.0, 130.0, 23.0],
#        [Timestamp('2022-01-03 00:00:00'), 102.0, 102.0, 21.0],
#        [Timestamp('2022-01-04 00:00:00'), nan, nan, 36.0],
#        [Timestamp('2022-01-05 00:00:00'), 111.0, 111.0, nan],
#        [Timestamp('2022-01-06 00:00:00'), nan, nan, 31.0],
#        [Timestamp('2022-01-06 00:00:00'), 124.0, 124.0, 25.0]],
#       dtype=object)

# %%
df.axes
# Out:
# [Index(['Thứ 2', 'Thứ 3', 'Thứ 4', 'Thứ 5', 'Thứ 6', 'Thứ 7', 'Chủ nhật'], dtype='object'),
#  Index(['date', 'volumes_max', 'volumes', 'temperature'], dtype='object')]

# %%
df.ndim
# Out:
# 2

# %%
df.size
# Out:
# 28

# %%
df.shape
# Out:
# (7, 4)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7 entries, Thứ 2 to Chủ nhật
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         7 non-null      datetime64[ns]
#  1   volumes_max  5 non-null      float64
#  2   volumes      5 non-null      float64
#  3   temperature  6 non-null      float64
# dtypes: datetime64[ns](1), float64(3)
# memory usage: 580.0+ bytes

# %%
df.memory_usage()
# Out:
# Index          356
# date            56
# volumes_max     56
# volumes         56
# temperature     56
# dtype: int64

# %%
df.empty
# Out:
# False

# %%
data = {'date' :[],
        'volumes_max' : [],
        'volumes': [],
        'temperature' : []}
df = pd.DataFrame(data)
df.empty
# Out:
# True

# %%
data = {'date' :[None],
        'volumes_max' : [None],
        'volumes': [None],
        'temperature' : [None]}
df = pd.DataFrame(data)
df.empty
# Out:
# False

# %%
exam_data = {'score': [12.5, 9, 16.5, None, 9, 20, 14.5, None, 8, 19],
'attempts': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
'qualify': ['yes', 'no', 'yes', 'no', 'no', 'yes', 'yes', 'no', 'no', 'yes']}
labels =['Anastasia', 'Dima', 'Katherine', 'James', 'Emily', 'Michael', 'Matthew', 'Laura', 'Kevin', 'Jonas']

df = pd.DataFrame(exam_data,index = labels)
df
# Out:
#            score  attempts qualify
# Anastasia   12.5         1     yes
# Dima         9.0         3      no
# Katherine   16.5         2     yes
# James        NaN         3      no
# Emily        9.0         2      no
# Michael     20.0         3     yes
# Matthew     14.5         1     yes
# Laura        NaN         1      no
# Kevin        8.0         2      no
# Jonas       19.0         1     yes

# %% [markdown]
# - Kiểm tra thông tin của bảng dữ liệu
# - Mô tả bảng dữ liệu
# - Kiểm tra kiểu dữ liệu của từng cột
# - Hiển thị ra số cột của bảng
# - Hiện thị ra số dòng của bảng
# - Hiển thị tổng bộ nhớ mà bảng này chiếm

# %% [markdown]
# ## Chuyển đổi

# %% [markdown]
# - DataFrame.astype(dtype) : Ép kiểu DataFrame
#
# - DataFrame.convert_dtypes() : Ép kiểu sang kiểu dữ liệu tốt nhất có thể sử dụng kiểu dữ liệu có hỗ trợ NA
#
# - DataFrame.copy() : Tạo một bản sao

# %%
from sklearn.datasets import load_wine
df = load_wine(as_frame=True).data
print(df.dtypes)
df.head()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 from sklearn.datasets import load_wine
#       2 df = load_wine(as_frame=True).data
#       3 print(df.dtypes)
#
# ModuleNotFoundError: No module named 'sklearn'

# %%
df.astype('int').head()
# Out:
#    alcohol  malic_acid  ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0       14           1    2                 15        127              2
# 1       13           1    2                 11        100              2
# 2       13           2    2                 18        101              2
# 3       14           1    2                 16        113              3
# 4       13           2    2                 21        118              2
#
#    flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity  hue  \
# 0           3                     0                2                5    1
# 1           2                     0                1                4    1
# 2           3                     0                2                5    1
# 3           3                     0                2                7    0
# 4           2                     0                1                4    1
#
#    od280/od315_of_diluted_wines  proline
# 0                             3     1065
# 1                             3     1050
# 2                             3     1185
# 3                             3     1480
# 4                             2      735

# %%
df.astype('bool').head()
# Out:
#    alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0     True        True  True               True       True           True
# 1     True        True  True               True       True           True
# 2     True        True  True               True       True           True
# 3     True        True  True               True       True           True
# 4     True        True  True               True       True           True
#
#    flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity   hue  \
# 0        True                  True             True             True  True
# 1        True                  True             True             True  True
# 2        True                  True             True             True  True
# 3        True                  True             True             True  True
# 4        True                  True             True             True  True
#
#    od280/od315_of_diluted_wines  proline
# 0                          True     True
# 1                          True     True
# 2                          True     True
# 3                          True     True
# 4                          True     True

# %%
data = {'date' : pd.to_datetime(['01/01/2022','02/01/2022','03/01/2022','04/01/2022','05/01/2022','06/01/2022','06/01/2022'],format='%d/%m/%Y'),
        'volumes_max' : [120.0, 123.0, 102.0, None, 111.0, None, 124.0],
        'volumes': [120.0, 130.0, 102.0, None, 111.0	,None , 124.0],
        'temperature' : [22.0, 23.0, 21.0, 36.0, None, 31.0, 25.0]}
df = pd.DataFrame(data)
df_ct = df.convert_dtypes()
print(df_ct.dtypes)
df_ct
# Out:
# date           datetime64[ns]
# volumes_max             Int64
# volumes                 Int64
# temperature             Int64
# dtype: object
#         date  volumes_max  volumes  temperature
# 0 2022-01-01          120      120           22
# 1 2022-01-02          123      130           23
# 2 2022-01-03          102      102           21
# 3 2022-01-04         <NA>     <NA>           36
# 4 2022-01-05          111      111         <NA>
# 5 2022-01-06         <NA>     <NA>           31
# 6 2022-01-06          124      124           25

# %%
data = [['An',9],['Bình',8],['Cường',8],['Diễm',10]]
df = pd.DataFrame(data,columns =['Tên','Điểm'])
df
# Out:
#      Tên  Điểm
# 0     An     9
# 1   Bình     8
# 2  Cường     8
# 3   Diễm    10

# %%
df_2 = df
df_2['Tên'] = pd.Series(['Bình','Cường','Diễm','Đạt'])
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 df_2 = df
#       2 df_2['Tên'] = pd.Series(['Bình','Cường','Diễm','Đạt'])
#       3 df
#
# NameError: name 'df' is not defined

# %%
data = [['An',9],['Bình',8],['Cường',8],['Diễm',10]]
df = pd.DataFrame(data,columns =['Tên','Điểm'])
df
# Out:
#      Tên  Điểm
# 0     An     9
# 1   Bình     8
# 2  Cường     8
# 3   Diễm    10

# %%
df_2 = df.copy()
df_2['Tên'] = pd.Series(['Bình','Cường','Diễm','Đạt'])
df
# Out:
#      Tên  Điểm
# 0     An     9
# 1   Bình     8
# 2  Cường     8
# 3   Diễm    10

# %% [markdown]
# ## Một vài thao tác với DataFrame cơ bản

# %% [markdown]
# ### Thao tác với cột

# %%
from sklearn.datasets import load_wine
df = load_wine(as_frame=True).data
df
# Out:
#      alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols
# 0      14.23        1.71  2.43               15.6      127.0           2.80  \
# 1      13.20        1.78  2.14               11.2      100.0           2.65
# 2      13.16        2.36  2.67               18.6      101.0           2.80
# 3      14.37        1.95  2.50               16.8      113.0           3.85
# 4      13.24        2.59  2.87               21.0      118.0           2.80
# ..       ...         ...   ...                ...        ...            ...
# 173    13.71        5.65  2.45               20.5       95.0           1.68
# 174    13.40        3.91  2.48               23.0      102.0           1.80
# 175    13.27        4.28  2.26               20.0      120.0           1.59
# 176    13.17        2.59  2.37               20.0      120.0           1.65
# 177    14.13        4.10  2.74               24.5       96.0           2.05
#
#      flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity   hue
# 0          3.06                  0.28             2.29             5.64  1.04  \
# 1          2.76                  0.26             1.28             4.38  1.05
# 2          3.24                  0.30             2.81             5.68  1.03
# 3          3.49                  0.24             2.18             7.80  0.86
# 4          2.69                  0.39             1.82             4.32  1.04
# ..          ...                   ...              ...              ...   ...
# 173        0.61                  0.52             1.06             7.70  0.64
# 174        0.75                  0.43             1.41             7.30  0.70
# 175        0.69                  0.43             1.35            10.20  0.59
# 176        0.68                  0.53             1.46             9.30  0.60
# 177        0.76                  0.56             1.35             9.20  0.61
#
#      od280/od315_of_diluted_wines  proline
# 0                            3.92   1065.0
# 1                            3.40   1050.0
# 2                            3.17   1185.0
# 3                            3.45   1480.0
# 4                            2.93    735.0
# ..                            ...      ...
# 173                          1.74    740.0
# 174                          1.56    750.0
# 175                          1.56    835.0
# 176                          1.62    840.0
# 177                          1.60    560.0
#
# [178 rows x 13 columns]

# %%
df.alcohol # Trả về Series
# Out:
# 0      14.23
# 1      13.20
# 2      13.16
# 3      14.37
# 4      13.24
#        ...
# 173    13.71
# 174    13.40
# 175    13.27
# 176    13.17
# 177    14.13
# Name: alcohol, Length: 178, dtype: float64

# %%
df.od280/od315_of_diluted_wines # không dùng cách này để lấy ra tên có ký tự đặc biệt

# %%
df['od280/od315_of_diluted_wines'] # Trả về Series
# Out:
# 0      3.92
# 1      3.40
# 2      3.17
# 3      3.45
# 4      2.93
#        ...
# 173    1.74
# 174    1.56
# 175    1.56
# 176    1.62
# 177    1.60
# Name: od280/od315_of_diluted_wines, Length: 178, dtype: float64

# %%
df[['alcohol','malic_acid']]  # Trả về bảng dữ liệu
# Out:
#      alcohol  malic_acid
# 0      14.23        1.71
# 1      13.20        1.78
# 2      13.16        2.36
# 3      14.37        1.95
# 4      13.24        2.59
# ..       ...         ...
# 173    13.71        5.65
# 174    13.40        3.91
# 175    13.27        4.28
# 176    13.17        2.59
# 177    14.13        4.10
#
# [178 rows x 2 columns]

# %%
df[['alcohol']]  > 14
# Out:
#      alcohol
# 0       True
# 1      False
# 2      False
# 3       True
# 4      False
# ..       ...
# 173    False
# 174    False
# 175    False
# 176    False
# 177     True
#
# [178 rows x 1 columns]

# %%
df[['alcohol']]  + 13
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[63], line 1
# ----> 1 df[['alcohol']]  + 13
#
# File c:\Users\nguye\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:3766, in DataFrame.__getitem__(self, key)
#    3764     if is_iterator(key):
#    3765         key = list(key)
# -> 3766     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3768 # take() does not accept boolean indexers
#    3769 if getattr(indexer, "dtype", None) == bool:
#
# File c:\Users\nguye\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py:5876, in Index._get_indexer_strict(self, key, axis_name)
#    5873 else:
#    5874     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 5876 self._raise_if_missing(keyarr, indexer, axis_name)
#    5878 keyarr = self.take(indexer)
#    5879 if isinstance(key, Index):
#    5880     # GH 42790 - Preserve name from an Index
#
# File c:\Users\nguye\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py:5935, in Index._raise_if_missing(self, key, indexer, axis_name)
#    5933     if use_interval_msg:
#    5934         key = list(key)
# -> 5935     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    5937 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#    5938 raise KeyError(f"{not_found} not in index")
#
# KeyError: "None of [Index(['alcohol'], dtype='object')] are in the [columns]"

# %%
df[['alcohol']] **2
# Out:
#       alcohol
# 0    202.4929
# 1    174.2400
# 2    173.1856
# 3    206.4969
# 4    175.2976
# ..        ...
# 173  187.9641
# 174  179.5600
# 175  176.0929
# 176  173.4489
# 177  199.6569
#
# [178 rows x 1 columns]

# %%
df**2
# Out:
#       alcohol  malic_acid     ash  alcalinity_of_ash  magnesium  \
# 0    202.4929      2.9241  5.9049             243.36    16129.0
# 1    174.2400      3.1684  4.5796             125.44    10000.0
# 2    173.1856      5.5696  7.1289             345.96    10201.0
# 3    206.4969      3.8025  6.2500             282.24    12769.0
# 4    175.2976      6.7081  8.2369             441.00    13924.0
# ..        ...         ...     ...                ...        ...
# 173  187.9641     31.9225  6.0025             420.25     9025.0
# 174  179.5600     15.2881  6.1504             529.00    10404.0
# 175  176.0929     18.3184  5.1076             400.00    14400.0
# 176  173.4489      6.7081  5.6169             400.00    14400.0
# 177  199.6569     16.8100  7.5076             600.25     9216.0
#
#      total_phenols  flavanoids  nonflavanoid_phenols  proanthocyanins  \
# 0           7.8400      9.3636                0.0784           5.2441
# 1           7.0225      7.6176                0.0676           1.6384
# 2           7.8400     10.4976                0.0900           7.8961
# 3          14.8225     12.1801                0.0576           4.7524
# 4           7.8400      7.2361                0.1521           3.3124
# ..             ...         ...                   ...              ...
# 173         2.8224      0.3721                0.2704           1.1236
# 174         3.2400      0.5625                0.1849           1.9881
# 175         2.5281      0.4761                0.1849           1.8225
# 176         2.7225      0.4624                0.2809           2.1316
# 177         4.2025      0.5776                0.3136           1.8225
#
#      color_intensity     hue  od280/od315_of_diluted_wines    proline
# 0            31.8096  1.0816                       15.3664  1134225.0
# 1            19.1844  1.1025                       11.5600  1102500.0
# 2            32.2624  1.0609                       10.0489  1404225.0
# 3            60.8400  0.7396                       11.9025  2190400.0
# 4            18.6624  1.0816                        8.5849   540225.0
# ..               ...     ...                           ...        ...
# 173          59.2900  0.4096                        3.0276   547600.0
# 174          53.2900  0.4900                        2.4336   562500.0
# 175         104.0400  0.3481                        2.4336   697225.0
# 176          86.4900  0.3600                        2.6244   705600.0
# 177          84.6400  0.3721                        2.5600   313600.0
#
# [178 rows x 13 columns]

# %% [markdown]
# ### Thao tác thêm sửa xóa cột

# %%
data = {'Toán':[9,8,8,10],'Lý':[7,6,4,8],'Hóa':[0,0,0,1]}
df = pd.DataFrame(data,index = ['An','Bình','Cường','Diễm'])
df
# Out:
#        Toán  Lý  Hóa
# An        9   7    0
# Bình      8   6    0
# Cường     8   4    0
# Diễm     10   8    1

# %%
df['Hóa'] = [6,7,8,8]
df
# Out:
#        Toán  Lý  Hóa
# An        9   7    6
# Bình      8   6    7
# Cường     8   4    8
# Diễm     10   8    8

# %%
df = df[['Toán','Hóa']]
df
# Out:
#    Toán  Hóa
# 0     9    0
# 1     8    0
# 2     8    0
# 3    10    1

# %%
df['Lý'] = [9,8,9,8]
df
# Out:
#        Toán  Hóa  Lý
# An        9    6   9
# Bình      8    7   8
# Cường     8    8   9
# Diễm     10    8   8

# %%
df = df[['Toán','Lý','Hóa']]
df
# Out:
#        Toán  Lý  Hóa
# An        9   9    6
# Bình      8   8    7
# Cường     8   9    8
# Diễm     10   8    8

# %% [markdown]
# ### Bài tập

# %%
from sklearn.datasets import load_wine

# %%
df = load_wine(as_frame=True).data
df.head()
# Out:
#    alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0    14.23        1.71  2.43               15.6      127.0           2.80
# 1    13.20        1.78  2.14               11.2      100.0           2.65
# 2    13.16        2.36  2.67               18.6      101.0           2.80
# 3    14.37        1.95  2.50               16.8      113.0           3.85
# 4    13.24        2.59  2.87               21.0      118.0           2.80
#
#    flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity   hue  \
# 0        3.06                  0.28             2.29             5.64  1.04
# 1        2.76                  0.26             1.28             4.38  1.05
# 2        3.24                  0.30             2.81             5.68  1.03
# 3        3.49                  0.24             2.18             7.80  0.86
# 4        2.69                  0.39             1.82             4.32  1.04
#
#    od280/od315_of_diluted_wines  proline
# 0                          3.92   1065.0
# 1                          3.40   1050.0
# 2                          3.17   1185.0
# 3                          3.45   1480.0
# 4                          2.93    735.0

# %%
target = load_wine(as_frame=True).target

# %% [markdown]
# - Lấy ra cột nồng độ cồn dưới dạng mảng
# - Lấy ra các cột nồng độ cồn, tỷ lệ tro
# - Lấy ra các cột liên quan đến hóa chất trong rượu
# - Lấy ra các cột liên quan đến mầu sắc
# - Lấy ra bảng df nhưng thứ tự các cột là đảo ngược
# - Sửa cột proline với giá trị mới bằng 1 phần 10 giá trị cũ
# - Thêm cột target vào bảng
# - Xóa cột 'od280/od315_of_diluted_wines'

# %%
data = {'Toán':[9,8,8,10],'Lý':[7,6,4,8],'Hóa':[0,0,0,1]}
df = pd.DataFrame(data,index = ['An','Bình','Cường','Diễm'])
df
# Out:
#        Toán  Lý  Hóa
# An        9   7    0
# Bình      8   6    0
# Cường     8   4    0
# Diễm     10   8    1

# %% [markdown]
# - Lấy ra điểm Toán của cả lớp
# - Sửa điểm Lý của Cường thành 5
# - Sửa điểm Hóa của cả lớp thành [6,7,8,9]

# %% [markdown]
# ## Lấy mẫu

# %% [markdown]
# - DataFrame.head(n) : Trả về n dòng đầu tiên
#
# - DataFrame.tail(n) : Trả về n dòng cuối cùng
#
# - DataFrame.sample([n, frac, replace, random_state]) : Trả về mẫu ngẫu nhiên
#   - n : Số lượng phần tử lấy mẫu
#   - frac : Tỷ lệ phần tử lấy mẫu
#   - replace : Cho phép mẫu có được lặp lại không
#   - random_state : Hạt giống cho ngẫu nhiên

# %%
from sklearn.datasets import load_wine
df = load_wine(as_frame=True).data

# %%
df
# Out:
#      alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0      14.23        1.71  2.43               15.6      127.0           2.80
# 1      13.20        1.78  2.14               11.2      100.0           2.65
# 2      13.16        2.36  2.67               18.6      101.0           2.80
# 3      14.37        1.95  2.50               16.8      113.0           3.85
# 4      13.24        2.59  2.87               21.0      118.0           2.80
# ..       ...         ...   ...                ...        ...            ...
# 173    13.71        5.65  2.45               20.5       95.0           1.68
# 174    13.40        3.91  2.48               23.0      102.0           1.80
# 175    13.27        4.28  2.26               20.0      120.0           1.59
# 176    13.17        2.59  2.37               20.0      120.0           1.65
# 177    14.13        4.10  2.74               24.5       96.0           2.05
#
#      flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity   hue  \
# 0          3.06                  0.28             2.29             5.64  1.04
# 1          2.76                  0.26             1.28             4.38  1.05
# 2          3.24                  0.30             2.81             5.68  1.03
# 3          3.49                  0.24             2.18             7.80  0.86
# 4          2.69                  0.39             1.82             4.32  1.04
# ..          ...                   ...              ...              ...   ...
# 173        0.61                  0.52             1.06             7.70  0.64
# 174        0.75                  0.43             1.41             7.30  0.70
# 175        0.69                  0.43             1.35            10.20  0.59
# 176        0.68                  0.53             1.46             9.30  0.60
# 177        0.76                  0.56             1.35             9.20  0.61
#
#      od280/od315_of_diluted_wines  proline
# 0                            3.92   1065.0
# 1                            3.40   1050.0
# 2                            3.17   1185.0
# 3                            3.45   1480.0
# 4                            2.93    735.0
# ..                            ...      ...
# 173                          1.74    740.0
# 174                          1.56    750.0
# 175                          1.56    835.0
# 176                          1.62    840.0
# 177                          1.60    560.0
#
# [178 rows x 13 columns]

# %%
df.head() #lấy 5 dòng đầu tiên
# Out:
#    alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0    14.23        1.71  2.43               15.6      127.0           2.80
# 1    13.20        1.78  2.14               11.2      100.0           2.65
# 2    13.16        2.36  2.67               18.6      101.0           2.80
# 3    14.37        1.95  2.50               16.8      113.0           3.85
# 4    13.24        2.59  2.87               21.0      118.0           2.80
#
#    flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity   hue  \
# 0        3.06                  0.28             2.29             5.64  1.04
# 1        2.76                  0.26             1.28             4.38  1.05
# 2        3.24                  0.30             2.81             5.68  1.03
# 3        3.49                  0.24             2.18             7.80  0.86
# 4        2.69                  0.39             1.82             4.32  1.04
#
#    od280/od315_of_diluted_wines  proline
# 0                          3.92   1065.0
# 1                          3.40   1050.0
# 2                          3.17   1185.0
# 3                          3.45   1480.0
# 4                          2.93    735.0

# %%
df.tail() # lấy ra 5 dòng cuối cùng
# Out:
#      alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 173    13.71        5.65  2.45               20.5       95.0           1.68
# 174    13.40        3.91  2.48               23.0      102.0           1.80
# 175    13.27        4.28  2.26               20.0      120.0           1.59
# 176    13.17        2.59  2.37               20.0      120.0           1.65
# 177    14.13        4.10  2.74               24.5       96.0           2.05
#
#      flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity   hue  \
# 173        0.61                  0.52             1.06              7.7  0.64
# 174        0.75                  0.43             1.41              7.3  0.70
# 175        0.69                  0.43             1.35             10.2  0.59
# 176        0.68                  0.53             1.46              9.3  0.60
# 177        0.76                  0.56             1.35              9.2  0.61
#
#      od280/od315_of_diluted_wines  proline
# 173                          1.74    740.0
# 174                          1.56    750.0
# 175                          1.56    835.0
# 176                          1.62    840.0
# 177                          1.60    560.0

# %%
df.head(10) # lấy ra 10 dòng đầu tiền
# Out:
#    alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0    14.23        1.71  2.43               15.6      127.0           2.80
# 1    13.20        1.78  2.14               11.2      100.0           2.65
# 2    13.16        2.36  2.67               18.6      101.0           2.80
# 3    14.37        1.95  2.50               16.8      113.0           3.85
# 4    13.24        2.59  2.87               21.0      118.0           2.80
# 5    14.20        1.76  2.45               15.2      112.0           3.27
# 6    14.39        1.87  2.45               14.6       96.0           2.50
# 7    14.06        2.15  2.61               17.6      121.0           2.60
# 8    14.83        1.64  2.17               14.0       97.0           2.80
# 9    13.86        1.35  2.27               16.0       98.0           2.98
#
#    flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity   hue  \
# 0        3.06                  0.28             2.29             5.64  1.04
# 1        2.76                  0.26             1.28             4.38  1.05
# 2        3.24                  0.30             2.81             5.68  1.03
# 3        3.49                  0.24             2.18             7.80  0.86
# 4        2.69                  0.39             1.82             4.32  1.04
# 5        3.39                  0.34             1.97             6.75  1.05
# 6        2.52                  0.30             1.98             5.25  1.02
# 7        2.51                  0.31             1.25             5.05  1.06
# 8        2.98                  0.29             1.98             5.20  1.08
# 9        3.15                  0.22             1.85             7.22  1.01
#
#    od280/od315_of_diluted_wines  proline
# 0                          3.92   1065.0
# 1                          3.40   1050.0
# 2                          3.17   1185.0
# 3                          3.45   1480.0
# 4                          2.93    735.0
# 5                          2.85   1450.0
# 6                          3.58   1290.0
# 7                          3.58   1295.0
# 8                          2.85   1045.0
# 9                          3.55   1045.0

# %%
df.sample(5) # Lấy ngẫu nhiên 5 dòng
# Out:
#      alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 134    12.51        1.24  2.25               17.5       85.0           2.00
# 108    12.22        1.29  1.94               19.0       92.0           2.36
# 112    11.76        2.68  2.92               20.0      103.0           1.75
# 140    12.93        2.81  2.70               21.0       96.0           1.54
# 98     12.37        1.07  2.10               18.5       88.0           3.52
#
#      flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity   hue  \
# 134        0.58                  0.60             1.25             5.45  0.75
# 108        2.04                  0.39             2.08             2.70  0.86
# 112        2.03                  0.60             1.05             3.80  1.23
# 140        0.50                  0.53             0.75             4.60  0.77
# 98         3.75                  0.24             1.95             4.50  1.04
#
#      od280/od315_of_diluted_wines  proline
# 134                          1.51    650.0
# 108                          3.02    312.0
# 112                          2.50    607.0
# 140                          2.31    600.0
# 98                           2.77    660.0

# %%
df.sample(frac = 0.2) # Lấy ngẫu nhiên 20% không cho phép lặp lại

# %%
df.sample(frac = 2, replace = True) # Lấy ngẫu nhiên 200% có cho phép lặp lại

# %%
from sklearn.datasets import load_wine
df = load_wine(as_frame=True).data

# %% [markdown]
# - Hãy lấy ra 15 dòng đầu tiên
# - Hãy lấy ra 2 dòng cuối
# - Hãy lấy ra 50 dòng đầu tiên
# - Hãy lấy ra 50 dòng cuối cùng
# - Hãy lấy ngẫu nhiên 20 dòng
# - Hãy lấy ngẫu nhiên 80% dữ liệu

# %% [markdown]
# ## Lựa chọn dòng cột

# %% [markdown]
# - DataFrame.xs(key[, axis, level, drop_level]) : Lấy ra dữ liệu theo cột hoặc dòng
# - DataFrame.get(key) : Lấy dữ liệu theo tên cột
#
# - DataFrame.take(indices[, axis]) : Lấy ra dựa danh sách các vị trí
#   - indices : Danh sách các chỉ số
#
# - DataFrame.truncate([before, after, axis]) : Lấy ra dựa trên khoảng
#   - before : Chỉ số bắt đầu
#   - after : Chỉ số kết thúc

# %%
from sklearn.datasets import load_wine
df = load_wine(as_frame=True).data
df.head()
# Out:
#    alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols
# 0    14.23        1.71  2.43               15.6      127.0           2.80  \
# 1    13.20        1.78  2.14               11.2      100.0           2.65
# 2    13.16        2.36  2.67               18.6      101.0           2.80
# 3    14.37        1.95  2.50               16.8      113.0           3.85
# 4    13.24        2.59  2.87               21.0      118.0           2.80
#
#    flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity   hue
# 0        3.06                  0.28             2.29             5.64  1.04  \
# 1        2.76                  0.26             1.28             4.38  1.05
# 2        3.24                  0.30             2.81             5.68  1.03
# 3        3.49                  0.24             2.18             7.80  0.86
# 4        2.69                  0.39             1.82             4.32  1.04
#
#    od280/od315_of_diluted_wines  proline
# 0                          3.92   1065.0
# 1                          3.40   1050.0
# 2                          3.17   1185.0
# 3                          3.45   1480.0
# 4                          2.93    735.0

# %%
df.get('alcohol') # Lấy theo tên cột và trả về series
# Out:
# 0      14.23
# 1      13.20
# 2      13.16
# 3      14.37
# 4      13.24
#        ...
# 173    13.71
# 174    13.40
# 175    13.27
# 176    13.17
# 177    14.13
# Name: alcohol, Length: 178, dtype: float64

# %%
df.get(['alcohol']) # Lấy theo tên cột và trả về DataFrame
# Out:
#      alcohol
# 0      14.23
# 1      13.20
# 2      13.16
# 3      14.37
# 4      13.24
# ..       ...
# 173    13.71
# 174    13.40
# 175    13.27
# 176    13.17
# 177    14.13
#
# [178 rows x 1 columns]

# %%
df.get(['alcohol','ash','flavanoids','color_intensity'])
# Out:
#      alcohol   ash  flavanoids  color_intensity
# 0      14.23  2.43        3.06             5.64
# 1      13.20  2.14        2.76             4.38
# 2      13.16  2.67        3.24             5.68
# 3      14.37  2.50        3.49             7.80
# 4      13.24  2.87        2.69             4.32
# ..       ...   ...         ...              ...
# 173    13.71  2.45        0.61             7.70
# 174    13.40  2.48        0.75             7.30
# 175    13.27  2.26        0.69            10.20
# 176    13.17  2.37        0.68             9.30
# 177    14.13  2.74        0.76             9.20
#
# [178 rows x 4 columns]

# %%
df.get('alcol') # nếu không có thì không trả về gì cả

# %%
df.xs(0)  # lấy theo chỉ số
# Out:
# alcohol                           14.23
# malic_acid                         1.71
# ash                                2.43
# alcalinity_of_ash                 15.60
# magnesium                        127.00
# total_phenols                      2.80
# flavanoids                         3.06
# nonflavanoid_phenols               0.28
# proanthocyanins                    2.29
# color_intensity                    5.64
# hue                                1.04
# od280/od315_of_diluted_wines       3.92
# proline                         1065.00
# Name: 0, dtype: float64

# %%
df.xs(0)
# Out:
# alcohol                           14.23
# malic_acid                         1.71
# ash                                2.43
# alcalinity_of_ash                 15.60
# magnesium                        127.00
# total_phenols                      2.80
# flavanoids                         3.06
# nonflavanoid_phenols               0.28
# proanthocyanins                    2.29
# color_intensity                    5.64
# hue                                1.04
# od280/od315_of_diluted_wines       3.92
# proline                         1065.00
# Name: 0, dtype: float64

# %%
df.xs(178) # nếu không có thì báo lỗi

# %%
df.xs('alcohol',axis ='columns') # lấy theo tên cột
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\nguye\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py:3652, in Index.get_loc(self, key)
#    3651 try:
# -> 3652     return self._engine.get_loc(casted_key)
#    3653 except KeyError as err:
#
# File c:\Users\nguye\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\nguye\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'alcohol'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[107], line 1
# ----> 1 df.xs('alcohol',axis ='columns') # lấy theo tên cột
#
# File c:\Users\nguye\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\generic.py:4082, in NDFrame.xs(self, key, axis, level, drop_level)
#    4080 if axis == 1:
#    4081     if drop_level:
# -> 4082         return self[key]
#    4083     index = self.columns
#    4084 else:
#
# File c:\Users\nguye\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:3760, in DataFrame.__getitem__(self, key)
#    3758 if self.columns.nlevels > 1:
#    3759     return self._getitem_multilevel(key)
# -> 3760 indexer = self.columns.get_loc(key)
#    3761 if is_integer(indexer):
#    3762     indexer = [indexer]
#
# File c:\Users\nguye\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py:3654, in Index.get_loc(self, key)
#    3652     return self._engine.get_loc(casted_key)
#    3653 except KeyError as err:
# -> 3654     raise KeyError(key) from err
#    3655 except TypeError:
#    3656     # If we have a listlike key, _check_indexing_error will raise
#    3657     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3658     #  the TypeError.
#    3659     self._check_indexing_error(key)
#
# KeyError: 'alcohol'

# %%
df.take([2,3,5,6])
# Out:
#    alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 2    13.16        2.36  2.67               18.6      101.0           2.80
# 3    14.37        1.95  2.50               16.8      113.0           3.85
# 5    14.20        1.76  2.45               15.2      112.0           3.27
# 6    14.39        1.87  2.45               14.6       96.0           2.50
#
#    flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity   hue  \
# 2        3.24                  0.30             2.81             5.68  1.03
# 3        3.49                  0.24             2.18             7.80  0.86
# 5        3.39                  0.34             1.97             6.75  1.05
# 6        2.52                  0.30             1.98             5.25  1.02
#
#    od280/od315_of_diluted_wines  proline
# 2                          3.17   1185.0
# 3                          3.45   1480.0
# 5                          2.85   1450.0
# 6                          3.58   1290.0

# %%
df.take([2,3,5,6], axis= 'columns')
# Out:
#       ash  alcalinity_of_ash  total_phenols  flavanoids
# 0    2.43               15.6           2.80        3.06
# 1    2.14               11.2           2.65        2.76
# 2    2.67               18.6           2.80        3.24
# 3    2.50               16.8           3.85        3.49
# 4    2.87               21.0           2.80        2.69
# ..    ...                ...            ...         ...
# 173  2.45               20.5           1.68        0.61
# 174  2.48               23.0           1.80        0.75
# 175  2.26               20.0           1.59        0.69
# 176  2.37               20.0           1.65        0.68
# 177  2.74               24.5           2.05        0.76
#
# [178 rows x 4 columns]

# %%
df.truncate(before = 70, after = 90)

# %%
df.sort_index(axis = 'columns').truncate(before ='ash',after = 'hue',axis = 'columns')
# Out:
#       ash  color_intensity  flavanoids   hue
# 0    2.43             5.64        3.06  1.04
# 1    2.14             4.38        2.76  1.05
# 2    2.67             5.68        3.24  1.03
# 3    2.50             7.80        3.49  0.86
# 4    2.87             4.32        2.69  1.04
# ..    ...              ...         ...   ...
# 173  2.45             7.70        0.61  0.64
# 174  2.48             7.30        0.75  0.70
# 175  2.26            10.20        0.69  0.59
# 176  2.37             9.30        0.68  0.60
# 177  2.74             9.20        0.76  0.61
#
# [178 rows x 4 columns]

# %%
exam_data = {'name': ['Anastasia', 'Dima', 'Katherine', 'James', 'Emily', 'Michael', 'Matthew', 'Laura', 'Kevin', 'Jonas'],
'score': [12.5, 9, 16.5, np.nan, 9, 20, 14.5, np.nan, 8, 19],
'attempts': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
'qualify': ['yes', 'no', 'yes', 'no', 'no', 'yes', 'yes', 'no', 'no', 'yes']}
labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']

df = pd.DataFrame(exam_data,index = labels)
df
# Out:
#         name  score  attempts qualify
# a  Anastasia   12.5         1     yes
# b       Dima    9.0         3      no
# c  Katherine   16.5         2     yes
# d      James    NaN         3      no
# e      Emily    9.0         2      no
# f    Michael   20.0         3     yes
# g    Matthew   14.5         1     yes
# h      Laura    NaN         1      no
# i      Kevin    8.0         2      no
# j      Jonas   19.0         1     yes

# %% [markdown]
# - Lấy ra dữ liệu tại các dòng 2,3,5,7
# - Lấy ra tên và số lần thi của Dima, Katherine, Emily, Laura
# - Lấy ra các dòng từ d-h

# %%
df.take([2,3,5,6])
# Out:
#         name  score  attempts qualify
# c  Katherine   16.5         2     yes
# d      James    NaN         3      no
# f    Michael   20.0         3     yes
# g    Matthew   14.5         1     yes

# %%
a = df.get(['name','attempts'])
a
a.take([1,2,4,7])
# Out:
#         name  attempts
# b       Dima         3
# c  Katherine         2
# e      Emily         2
# h      Laura         1

# %%
df.sort_index().truncate(before ='d',after = 'h')
# Out:
#       name  score  attempts qualify
# d    James    NaN         3      no
# e    Emily    9.0         2      no
# f  Michael   20.0         3     yes
# g  Matthew   14.5         1     yes
# h    Laura    NaN         1      no

# %% [markdown]
# ## Truy cập DataFrame

# %% [markdown]
# - DataFrame.at : Truy cập tới một phần từ theo cặp tên dòng/cột
#
# - DataFrame.iat : Truy cập tới một phần tử theo cặp chỉ số dòng/cột
#
# - DataFrame.loc : Truy cập tới tập hợp các phần tử theo tên dòng và cột hoặc theo một mảng bool
#
# - DataFrame.iloc : Truy cập tới tập hợp các phần tử theo chỉ số dòng và cột

# %%
data = {'Toán':[9,8,8,10],'Lý':[7,6,4,8],'Hóa':[0,0,0,1]}
df = pd.DataFrame(data,index = ['An','Bình','Cường','Diễm'])
df
# Out:
#        Toán  Lý  Hóa
# An        9   7    0
# Bình      8   6    0
# Cường     8   4    0
# Diễm     10   8    1

# %%
df.at['An',"Toán"]
# Out:
# 9

# %%
df.at['Cường','Hóa'] = 9
df
# Out:
#        Toán  Văn  Lý  Hóa  Sinh
# An        9    8   7    8     8
# Bình      8    6   6    8     8
# Cường     8    7   4    9     7
# Diễm     10    9   8    9     9

# %%
df.iat[0,0]
# Out:
# 9

# %%
df.loc[:,'Toán']
# Out:
# An        9
# Bình      8
# Cường     8
# Diễm     10
# Name: Toán, dtype: int64

# %%
df.iloc[2,:]
# Out:
# Toán    8
# Lý      4
# Hóa     3
# Name: Cường, dtype: int64

# %%
df.loc['Diễm']
# Out:
# Toán    10
# Lý       8
# Hóa      1
# Name: Diễm, dtype: int64

# %%
df.iloc[1]
# Out:
# Toán    8
# Lý      6
# Hóa     0
# Name: Bình, dtype: int64

# %%
data = {'Toán':[9,8,8,10],'Văn':[8,6,7,9],'Lý':[7,6,4,8],'Hóa':[8,8,9,9],'Sinh':[8,8,7,9]}
df = pd.DataFrame(data,index = ['An','Bình','Cường','Diễm'])
df
# Out:
#        Toán  Văn  Lý  Hóa  Sinh
# An        9    8   7    8     8
# Bình      8    6   6    8     8
# Cường     8    7   4    9     7
# Diễm     10    9   8    9     9

# %% [markdown]
# - Lấy ra điểm Toán của cả lớp
# - Lấy ra điểm của bạn Diễm
#   - Tính điểm trung bình của bạn Diễm
# - Lấy ra điểm Toán của bạn An
# - Lấy ra điểm Lý của bạn Cường
# - Lẩy ra điểm Văn Hóa của bạn Bình và bạn Diễm
# - Lấy ra điểm Sinh Lý của bạn An và bạn Cường
# - Sửa điểm Lý của Cường thành 5
# - Sửa điểm Bình thành [6,7,8,9,10]

# %%
df.loc[:,'Toán']
# Out:
# An        9
# Bình      8
# Cường     8
# Diễm     10
# Name: Toán, dtype: int64

# %%
df.loc['Diễm']
# Out:
# Toán    10
# Văn      9
# Lý       8
# Hóa      9
# Sinh     9
# Name: Diễm, dtype: int64

# %%
df.at['An',"Toán"]
# Out:
# 9

# %%
df.at['Cường',"Lý"]
# Out:
# 4

# %%
a = df.get(['Văn','Hóa'])
a.take([1,3])
# Out:
#       Văn  Hóa
# Bình    6    8
# Diễm    9    9

# %%
a = df.get(['Sinh','Lý'])
a.take([0,2])
# Out:
#        Sinh  Lý
# An        8   7
# Cường     7   4

# %% [markdown]
# ## Thêm và xóa

# %% [markdown]
# - DataFrame.insert(loc, column, value) : Thêm cột
#   - loc : Vị trí thêm
#   - column : Tên của cột thêm mới
#   - value : Giá trị của cột thêm vào
#
# - DataFrame.pop(item) : Xóa cột theo tên và trả về cột vừa xóa
#   - item : Tên của cột
#
# - DataFrame.drop([labels, axis]) : Xóa dòng hoặc cột
#   - labels : Tên muốn xóa
#   - axis : Trục tìm tên

# %%
data = {'Toán':[9,8,8,10],'Lý':[7,6,4,8],'Hóa':[8,8,9,9],'Sinh':[8,8,7,9]}
df = pd.DataFrame(data,index = ['An','Bình','Cường','Diễm'])
df
# Out:
#        Toán  Lý  Hóa  Sinh
# An        9   7    8     8
# Bình      8   6    8     8
# Cường     8   4    9     7
# Diễm     10   8    9     9

# %%
df.insert(1,'Văn',[7,7,6,8]) # Nếu thêm trùng tên mà không có allow_duplicates=True sẽ báo lỗi
df
# Out:
#        Toán  Văn  Lý  Hóa  Sinh
# An        9    7   7    8     8
# Bình      8    7   6    8     8
# Cường     8    6   4    9     7
# Diễm     10    8   8    9     9

# %%
pop_data= df.pop('Hóa') # Xóa cột mà không tồn tại sẽ báo lỗi
df
# Out:
#        Toán  Văn  Lý  Sinh
# An        9    7   7     8
# Bình      8    7   6     8
# Cường     8    6   4     7
# Diễm     10    8   8     9

# %%
pop_data
# Out:
# An       8
# Bình     8
# Cường    9
# Diễm     9
# Name: Hóa, dtype: int64

# %%
data = {'Toán':[9,8,8,10],'Văn':[8,6,7,9],'Lý':[7,6,4,8],'Hóa':[8,8,9,9],'Sinh':[8,8,7,9]}
df = pd.DataFrame(data,index = ['An','Bình','Cường','Diễm'])
df
# Out:
#        Toán  Văn  Lý  Hóa  Sinh
# An        9    8   7    8     8
# Bình      8    6   6    8     8
# Cường     8    7   4    9     7
# Diễm     10    9   8    9     9

# %%
df.drop(['Bình','An']) # Tạo một bản sao mới df gốc vẫn y nguyên
# Out:
#        Toán  Văn  Lý  Hóa  Sinh
# Cường     8    7   4    9     7
# Diễm     10    9   8    9     9

# %%
df.drop(['Sinh','Lý'],axis = 'columns')
# Out:
#        Toán  Văn  Hóa
# An        9    8    8
# Bình      8    6    8
# Cường     8    7    9
# Diễm     10    9    9

# %%
data = {'Toán':[9,8,8,10],'Lý':[7,6,4,8],'Hóa':[0,0,0,1]}
df = pd.DataFrame(data,index = ['An','Bình','Cường','Diễm'])
df
# Out:
#        Toán  Lý  Hóa
# An        9   7    0
# Bình      8   6    0
# Cường     8   4    0
# Diễm     10   8    1

# %% [markdown]
# - Thêm điểm Văn vào vị trí phía sau điểm Toán với giá trị là [7,7,6,8]
# - Thêm điểm Tiếng Anh vào vị trí sau điểm Lý với giá trị là [7,8,9,10]
# - Sửa điểm Hóa thành [5,7,6,8] (Sửa sao cho vị trí của cột điểm không thay đổi). Lưu lại điểm cũ

# %% [markdown]
# ## Truy vấn

# %% [markdown]
# - Tìm kiếm
#   - DataFrame.isin(values) : Kiểu tra các phẩn tử trong DataFrame có nằm trong values không
#     - values tập hợp các phần tử cần tìm
#
#   - DataFrame.query(expr) : Truy vấn các cột của DataFrame bằng biểu thức logic
#     - expr : Biểu thức thể hiện điều kiện tìm kiếm
#
# - Tìm kiếm theo tên cột hoặc tên dòng
#   - DataFrame.filter([items, like, regex, axis]) : Lấy ra dòng hoặc cột theo dựa theo tên
#     - items : Tên chính xác
#     - like : Có chứa ký tự
#     - regex : Biểu thức chính quy
#     - axis : Chọn trục
#
# - Tìm vị trí max vị trí min
#   - DataFrame.idxmax([axis, skipna, numeric_only]) : Trả về chỉ số vị trí của giá trị lớn nhất đầu tiên xuất hiện
#     - axis : Chọn trục lấy max
#     - skipna : Lựa chọn có bỏ qua giá trị NA hay không
#
#   - DataFrame.idxmin([axis, skipna, numeric_only]) : Trả về chỉ số vị trí của giá trị lớn nhỏ đầu tiên xuất hiện
#     - axis : Chọn trục lấy min
#     - skipna : Lựa chọn có bỏ qua giá trị NA hay không
#
#
# - Tìm kiếm theo thời gian
#
#   - DataFrame.at_time(time) : Lựa chọn giá trị tại một thời điểm trong ngày
#
#   - DataFrame.between_time(start_time, end_time) : Lựa chọn những giá trị nằm trong một khoảng thời gian trong ngày
#     - start_time : Thời gian bắt đầu khoảng
#     - end_time : Thời gian kết thúc khoảng
#   - DataFrame.first(offset) : Lựa chọn khoảng thời gian đầu
#
#   - DataFrame.last(offset) : Lựa chọn khoảng thời gian cuối

# %% [markdown]
# ### Truy vấn DataFrame (phần 1)

# %%
from sklearn.datasets import load_wine
df = load_wine(as_frame=True).data
df.head()
# Out:
#    alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols
# 0    14.23        1.71  2.43               15.6      127.0           2.80  \
# 1    13.20        1.78  2.14               11.2      100.0           2.65
# 2    13.16        2.36  2.67               18.6      101.0           2.80
# 3    14.37        1.95  2.50               16.8      113.0           3.85
# 4    13.24        2.59  2.87               21.0      118.0           2.80
#
#    flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity   hue
# 0        3.06                  0.28             2.29             5.64  1.04  \
# 1        2.76                  0.26             1.28             4.38  1.05
# 2        3.24                  0.30             2.81             5.68  1.03
# 3        3.49                  0.24             2.18             7.80  0.86
# 4        2.69                  0.39             1.82             4.32  1.04
#
#    od280/od315_of_diluted_wines  proline
# 0                          3.92   1065.0
# 1                          3.40   1050.0
# 2                          3.17   1185.0
# 3                          3.45   1480.0
# 4                          2.93    735.0

# %%
df.describe()
# Out:
#           alcohol  malic_acid         ash  alcalinity_of_ash   magnesium  \
# count  178.000000  178.000000  178.000000         178.000000  178.000000
# mean    13.000618    2.336348    2.366517          19.494944   99.741573
# std      0.811827    1.117146    0.274344           3.339564   14.282484
# min     11.030000    0.740000    1.360000          10.600000   70.000000
# 25%     12.362500    1.602500    2.210000          17.200000   88.000000
# 50%     13.050000    1.865000    2.360000          19.500000   98.000000
# 75%     13.677500    3.082500    2.557500          21.500000  107.000000
# max     14.830000    5.800000    3.230000          30.000000  162.000000
#
#        total_phenols  flavanoids  nonflavanoid_phenols  proanthocyanins  \
# count     178.000000  178.000000            178.000000       178.000000
# mean        2.295112    2.029270              0.361854         1.590899
# std         0.625851    0.998859              0.124453         0.572359
# min         0.980000    0.340000              0.130000         0.410000
# 25%         1.742500    1.205000              0.270000         1.250000
# 50%         2.355000    2.135000              0.340000         1.555000
# 75%         2.800000    2.875000              0.437500         1.950000
# max         3.880000    5.080000              0.660000         3.580000
#
#        color_intensity         hue  od280/od315_of_diluted_wines      proline
# count       178.000000  178.000000                    178.000000   178.000000
# mean          5.058090    0.957449                      2.611685   746.893258
# std           2.318286    0.228572                      0.709990   314.907474
# min           1.280000    0.480000                      1.270000   278.000000
# 25%           3.220000    0.782500                      1.937500   500.500000
# 50%           4.690000    0.965000                      2.780000   673.500000
# 75%           6.200000    1.120000                      3.170000   985.000000
# max          13.000000    1.710000                      4.000000  1680.000000

# %% [markdown]
# - Lấy ra những dòng có chỉ số 'hue' thuộc top 25%
# - Lấy ra những dòng có chỉ số 'alcohol' thuộc 25% đến 75%
# - Lấy ra những dòng có chỉ số 'malic_acid' thuộc bottom 25%
# - Lấy ra những dòng có đồng thời chỉ số 'alcohol' top 25% và 'malic_acid' bottom 25%
#
# Gợi ý:
# - Toán tử và là &
# - Toán tử hoặc là |
# - Toán tử phủ định là ~

# %%
data = {'Toán':[9,8,8,10],'Lý':[7,6,4,8],'Hóa':[0,0,0,1]}
df = pd.DataFrame(data,index = ['An','Bình','Cường','Diễm'])
df
# Out:
#        Toán  Lý  Hóa
# An        9   7    0
# Bình      8   6    0
# Cường     8   4    0
# Diễm     10   8    1

# %% [markdown]
# - Lấy ra nhưng dòng có bạn điểm 10 (bất kỳ môn nào)
# - Lẩy ra những dòng có bạn điểm dưới 4 ( bất kỳ môn nào)
# - Lấy ra những dòng mà có điểm Toán khác 8
# <!-- df[((df<=4)).apply(np.any,axis = 'columns')] -->

# %%
exam_data = {'name': ['Anastasia', 'Dima', 'Katherine', 'James', 'Emily', 'Michael', 'Matthew', 'Laura', 'Kevin', 'Jonas'],
'score': [12.5, 9, 16.5, np.nan, 9, 20, 14.5, np.nan, 8, 19],
'attempts': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
'qualify': ['yes', 'no', 'yes', 'no', 'no', 'yes', 'yes', 'no', 'no', 'yes']}
labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']

df = pd.DataFrame(exam_data,index = labels)
df
# Out:
#         name  score  attempts qualify
# a  Anastasia   12.5         1     yes
# b       Dima    9.0         3      no
# c  Katherine   16.5         2     yes
# d      James    NaN         3      no
# e      Emily    9.0         2      no
# f    Michael   20.0         3     yes
# g    Matthew   14.5         1     yes
# h      Laura    NaN         1      no
# i      Kevin    8.0         2      no
# j      Jonas   19.0         1     yes

# %% [markdown]
# - Lấy ra thông tin của những người thi đạt
# - Lấy ra thông tin của những người không đạt tiêu chuẩn
# - Lấy ra thông tin của những người không có điểm
# - Lấy ra thông tin của những với số lần thi là nhiều nhất
# - Lấy ra thông tin của những người có số lần thi lớn hơn hoặc bằng 2
# - Lấy ra thông tin của những người thi đạt và chỉ thi 1 lần
# - Lấy ra thông tin của những người thi không đạt hoặc thi 3 lần
# - Lấy ra thông tin của những người có tên với chữ cái bắt đầu nằm trong khoảng A-L  [A, B, C, D, E, F, G, H, I ,J, K, L]

# %% [markdown]
# ### Truy vấn DataFrame (phần 2)
# - DataFrame.isin(values) : Kiểu tra các phẩn tử trong DataFrame có nằm trong values không
#   - values tập hợp các phần tử cần tìm
#
# - DataFrame.query(expr) : Truy vấn các cột của DataFrame bằng biểu thức logic
#   - expr : Biểu thức thể hiện điều kiện tìm kiếm

# %%
data = {'Toán':[9,8,8,10],'Lý':[7,6,4,8],'Hóa':[0,0,0,1]}
df = pd.DataFrame(data,index = ['An','Bình','Cường','Diễm'])
df
# Out:
#        Toán  Lý  Hóa
# An        9   7    0
# Bình      8   6    0
# Cường     8   4    0
# Diễm     10   8    1

# %%
df.isin([8,9,10])
# Out:
#        Toán     Lý    Hóa
# An     True  False  False
# Bình   True  False  False
# Cường  True  False  False
# Diễm   True   True  False

# %%
df[df['Toán'].isin([9,10])]
# Out:
#       Toán  Lý  Hóa
# An       9   7    0
# Diễm    10   8    1

# %%
df[df['Lý'].isin([8,9,10])]
# Out:
#       Toán  Lý  Hóa
# Diễm    10   8    1

# %%
df[df['Hóa'].isin([0])]
# Out:
#        Toán  Lý  Hóa
# An        9   7    0
# Bình      8   6    0
# Cường     8   4    0

# %%
df.query('Toán > 9')
# Out:
#       Toán  Lý  Hóa
# Diễm    10   8    1

# %%
df[df['Toán']>9]
# Out:
#       Toán  Lý  Hóa
# Diễm    10   8    1

# %%
df.query('(Toán + Lý)>15')
# Out:
#       Toán  Lý  Hóa
# An       9   7    0
# Diễm    10   8    1

# %%
df.query('Toán > 9 or Toán <= 8')
# Out:
#        Toán  Lý  Hóa
# Bình      8   6    0
# Cường     8   4    0
# Diễm     10   8    1

# %%
df[(df['Toán']>9)|(df['Toán']<=8)]
# Out:
#        Toán  Lý  Hóa
# Bình      8   6    0
# Cường     8   4    0
# Diễm     10   8    1

# %%
df.query('not (Toán == 9)')
# Out:
#        Toán  Lý  Hóa
# Bình      8   6    0
# Cường     8   4    0
# Diễm     10   8    1

# %%
df.query('(Toán != 9)')
# Out:
#        Toán  Lý  Hóa
# Bình      8   6    0
# Cường     8   4    0
# Diễm     10   8    1

# %%
df[~(df['Toán']==9)]
# Out:
#        Toán  Lý  Hóa
# Bình      8   6    0
# Cường     8   4    0
# Diễm     10   8    1

# %%
df.query('(Toán + Lý + Hóa)/3 >5')
# Out:
#       Toán  Lý  Hóa
# An       9   7    0
# Diễm    10   8    1

# %%
df.query('Toán in [8,10]')
# Out:
#        Toán  Lý  Hóa
# Bình      8   6    0
# Cường     8   4    0
# Diễm     10   8    1

# %%
df.query('[8,9] in Toán')
# Out:
#        Toán  Lý  Hóa
# An        9   7    0
# Bình      8   6    0
# Cường     8   4    0

# %%
df.query('Toán not in [9]')
# Out:
#        Toán  Lý  Hóa
# Bình      8   6    0
# Cường     8   4    0
# Diễm     10   8    1

# %%
from sklearn.datasets import load_wine
df = load_wine(as_frame=True).data
df.describe()
# Out:
#           alcohol  malic_acid         ash  alcalinity_of_ash   magnesium
# count  178.000000  178.000000  178.000000         178.000000  178.000000  \
# mean    13.000618    2.336348    2.366517          19.494944   99.741573
# std      0.811827    1.117146    0.274344           3.339564   14.282484
# min     11.030000    0.740000    1.360000          10.600000   70.000000
# 25%     12.362500    1.602500    2.210000          17.200000   88.000000
# 50%     13.050000    1.865000    2.360000          19.500000   98.000000
# 75%     13.677500    3.082500    2.557500          21.500000  107.000000
# max     14.830000    5.800000    3.230000          30.000000  162.000000
#
#        total_phenols  flavanoids  nonflavanoid_phenols  proanthocyanins
# count     178.000000  178.000000            178.000000       178.000000  \
# mean        2.295112    2.029270              0.361854         1.590899
# std         0.625851    0.998859              0.124453         0.572359
# min         0.980000    0.340000              0.130000         0.410000
# 25%         1.742500    1.205000              0.270000         1.250000
# 50%         2.355000    2.135000              0.340000         1.555000
# 75%         2.800000    2.875000              0.437500         1.950000
# max         3.880000    5.080000              0.660000         3.580000
#
#        color_intensity         hue  od280/od315_of_diluted_wines      proline
# count       178.000000  178.000000                    178.000000   178.000000
# mean          5.058090    0.957449                      2.611685   746.893258
# std           2.318286    0.228572                      0.709990   314.907474
# min           1.280000    0.480000                      1.270000   278.000000
# 25%           3.220000    0.782500                      1.937500   500.500000
# 50%           4.690000    0.965000                      2.780000   673.500000
# 75%           6.200000    1.120000                      3.170000   985.000000
# max          13.000000    1.710000                      4.000000  1680.000000

# %% [markdown]
# - Lấy ra những dòng có nồng độ cồn đạt max hoặc min (Dùng cả 2)
# - Lấy ra những dòng có chỉ số 'hue' dạt max hoặc min (Dùng cả 2)
# - Lấy ra những dòng có chỉ số 'malic_acid' thuộc một trong nhưng con số sau [0.74,1.6,1.8,3,5.8] (Dùng cả 2)
# - Lấy ra những dòng có chỉ số 'total_phenols' lớn hơn 'flavanoids'
# - Lấy ra những dòng có chỉ số 'malic_acid' lớn hơn 'ash'

# %%
df.query()

# %%
data = {'Toán':[9,8,8,10],'Lý':[7,6,4,8],'Hóa':[8,8,9,9]}
df = pd.DataFrame(data,index = ['An','Bình','Cường','Diễm'])
df
# Out:
#        Toán  Lý  Hóa
# An        9   7    8
# Bình      8   6    8
# Cường     8   4    9
# Diễm     10   8    9

# %% [markdown]
# - Lấy ra bạn có điểm tổng lớn hơn 23

# %%
df.query('(Toán + Lý + Hóa)>23')
# Out:
#       Toán  Lý  Hóa
# An       9   7    8
# Diễm    10   8    9

# %%
exam_data = {'name': ['Anastasia', 'Dima', 'Katherine', 'James', 'Emily', 'Michael', 'Matthew', 'Laura', 'Kevin', 'Jonas'],
'score': [12.5, 9, 16.5, np.nan, 9, 20, 14.5, np.nan, 8, 19],
'attempts': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
'qualify': ['yes', 'no', 'yes', 'no', 'no', 'yes', 'yes', 'no', 'no', 'yes']}
labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']

df = pd.DataFrame(exam_data,index = labels)
df
# Out:
#         name  score  attempts qualify
# a  Anastasia   12.5         1     yes
# b       Dima    9.0         3      no
# c  Katherine   16.5         2     yes
# d      James    NaN         3      no
# e      Emily    9.0         2      no
# f    Michael   20.0         3     yes
# g    Matthew   14.5         1     yes
# h      Laura    NaN         1      no
# i      Kevin    8.0         2      no
# j      Jonas   19.0         1     yes

# %%
df[df.name.str[0].isin(['A','K'])]
# Out:
#         name  score  attempts qualify
# a  Anastasia   12.5         1     yes
# c  Katherine   16.5         2     yes
# i      Kevin    8.0         2      no

# %%
df[df.name.str[-1].isin(['a','s'])]
# Out:
#         name  score  attempts qualify
# a  Anastasia   12.5         1     yes
# b       Dima    9.0         3      no
# d      James    NaN         3      no
# h      Laura    NaN         1      no
# j      Jonas   19.0         1     yes

# %%
df.query('name.str[0] in ["A","K"]')
# Out:
#         name  score  attempts qualify
# a  Anastasia   12.5         1     yes
# c  Katherine   16.5         2     yes
# i      Kevin    8.0         2      no

# %%
df.query('name.str[-1] in ["a","s"]')
# Out:
#         name  score  attempts qualify
# a  Anastasia   12.5         1     yes
# b       Dima    9.0         3      no
# d      James    NaN         3      no
# h      Laura    NaN         1      no
# j      Jonas   19.0         1     yes

# %% [markdown]
# - Lấy ra thông tin của những người thi được trên 15 điểm
# - Lấy ra thông tin của những người thi được dưới 10 điểm
# - Lấy ra thông tin của những người không có điểm
# - Lấy ra thông tin của những người có  điểm trên số lần thi lớn hơn 7
# - Lấy ra thông tin của những người có tên với chữ cái bắt đầu là A hoặc K
# - Lấy ra thông tin của những người có tên với chữ cái kết thúc bằng chữ a hoặc s
# - Lấy ra thông tin của những người thi đạt

# %% [markdown]
# **Ở đây có lời giải**
#
# <!-- df.query('score > 15')
#
# df.query('score < 10')
#
# df.query('not (score ==score)')
# df[df.score.isin([np.nan])]
#
# df.query('score/attempts > 7')
#
# df[df.name.str[0].isin(['A','K'])]
# df.query("name.str[0]=='K' or name.str[0]=='A'")
#
# df[df.name.str[-1].isin(['a','s'])]
# df.query("name.str[-1]=='a' or name.str[-1]=='s'") -->

# %% [markdown]
# ### Truy vấn DataFrame (phần 3)
# - DataFrame.filter([items, like, regex, axis]) : Lấy ra dòng hoặc cột theo dựa theo tên
#   - items : Tên chính xác
#   - like : Có chứa ký tự
#   - regex : Biểu thức chính quy
#   - axis : Chọn trục

# %%
exam_data = {'score': [12.5, 9, 16.5, np.nan, 9, 20, 14.5, np.nan, 8, 19],
'attempts': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
'qualify': ['yes', 'no', 'yes', 'no', 'no', 'yes', 'yes', 'no', 'no', 'yes']}

df = pd.DataFrame(exam_data,index = ['Anastasia', 'Dima', 'Katherine', 'James', 'Emily', 'Michael', 'Matthew', 'Laura', 'Kevin', 'Jonas'])
df
# Out:
#            score  attempts qualify
# Anastasia   12.5         1     yes
# Dima         9.0         3      no
# Katherine   16.5         2     yes
# James        NaN         3      no
# Emily        9.0         2      no
# Michael     20.0         3     yes
# Matthew     14.5         1     yes
# Laura        NaN         1      no
# Kevin        8.0         2      no
# Jonas       19.0         1     yes

# %%
df.filter(items = ['score'])
# Out:
#            score
# Anastasia   12.5
# Dima         9.0
# Katherine   16.5
# James        NaN
# Emily        9.0
# Michael     20.0
# Matthew     14.5
# Laura        NaN
# Kevin        8.0
# Jonas       19.0

# %%
df.filter(items = ['score','attempts'])

# %%
df.filter(items = ['Dima','Emily'],axis = 'index')
# Out:
#        score  attempts qualify
# Dima     9.0         3      no
# Emily    9.0         2      no

# %%
df.filter(like = 's') # Có chứa chữ s
# Out:
#            score  attempts
# Anastasia   12.5         1
# Dima         9.0         3
# Katherine   16.5         2
# James        NaN         3
# Emily        9.0         2
# Michael     20.0         3
# Matthew     14.5         1
# Laura        NaN         1
# Kevin        8.0         2
# Jonas       19.0         1

# %%
df.filter(like = 's',axis = 'index') # Có chứa chữ s
# Out:
#            score  attempts qualify
# Anastasia   12.5         1     yes
# James        NaN         3      no
# Jonas       19.0         1     yes

# %%
df.filter(like = 'e',axis = 'index') # Có chứa chữ e là dòng
# Out:
#            score  attempts qualify
# Katherine   16.5         2     yes
# James        NaN         3      no
# Michael     20.0         3     yes
# Matthew     14.5         1     yes
# Kevin        8.0         2      no

# %%
df.filter(regex='e$',axis = 'index') # Kết thúc bởi chữ e
# Out:
#            score  attempts qualify
# Katherine   16.5         2     yes

# %%
df.filter(regex='a$',axis = 'index') # Kết thúc bởi chữ a
# Out:
#            score  attempts qualify
# Anastasia   12.5         1     yes
# Dima         9.0         3      no
# Laura        NaN         1      no

# %%
df.filter(regex ='^J.*s$',axis = 'index')
# Out:
#        score  attempts qualify
# James    NaN         3      no
# Jonas   19.0         1     yes

# %%
df.filter(regex ='^M.*e.{1}$',axis = 'index')
# Out:
#          score  attempts qualify
# Michael   20.0         3     yes
# Matthew   14.5         1     yes

# %%
df

# %% [markdown]
# - Lẩy ra thông tin của Anastasia, Katherine, Emily, Laura
# - Lấy ra thông tin của những người mà tên có chứa chữ s
# - Lấy ra thông tin của những người có tên với chữ cái bắt đầu là A hoặc K (Sử dụng biểu thức chính quy)
# - Lấy ra thông tin của những người có tên với chữ cái kết thúc bằng chữ a hoặc s(Sử dụng biểu thức chính quy)
# - Lấy ra thông tin của những người tên có chứa E hoặc e hoặc M hoặc m
# - Lấy ra thông tin của những người tên có chứa E và m hoặc M và e
# - Lấy ra thông tin của những người tên có chứa e và m hoặc m và e
# - Lấy ra thông tin của những người tên bắt đầu bởi chữ M và chữ cái gần cuối là e
# - Lấy ra thông tin của những người tên có 5 chữ cái và bắt đầu bởi chữ J
# - Lấy ra thông tin của những người tên có chứa sâu 'na'
#
# <!-- df.filter(regex='[EMem]',axis = 'index')
# df.filter(regex='E.*m|M.*e',axis = 'index')
# df.filter(regex='na',axis = 'index') -->

# %%
data=[['11-0000','Management Occupations','major','$131,200','0.6%'],
['11-1000','Top Executives','minor','$129,050','1.1%'],
['11-1011','Chief Executives','detail','$246,440','1.6%'],
['11-1021','General and Operations Managers','detail','$122,860','1.1%'],
['11-1031','Legislators','detail','$71,100','1.7%'],
['11-2000','Advertising, Marketing, Promotions, Public Relations, and Sales Managers','minor','$152,320','0.4%'],
['11-2011','Advertising and Promotions Managers','detail','$147,050','2.2%'],
['11-2020','Marketing and Sales Managers','broad','$153,470','0.4%'],
['11-2021','Marketing Managers','detail','$158,280','0.6%'],
['11-2022','Sales Managers','detail','$150,530','0.4%'],
['11-2030','Public Relations and Fundraising Managers','broad','$142,610','0.7%'],
['11-2032','Public Relations Managers','detail','$150,030','0.8%'],
['11-2033','Fundraising Managers','detail','$124,450','1.3%'],
['11-3000','Operations Specialties Managers','minor','$148,190','0.4%'],
['11-3010','Administrative Services and Facilities Managers','broad','$112,440','0.3%']]
df = pd.DataFrame(data,
                  columns = ['Occupation code','Occupation tittle','Level','Wage','Increase'],
                  index = ['Trev@.com','Odeta@math','Niobe Ognen@xcom','Pt0l3m@is J@13h','Israa@gmail.com',
                           'MartaMarisa@hotmail.com','HannahCona@yahoo.com','Elijah Nicola','Consus Rodrigo','MartineAgatino@git.com',
                           'Lucyna Kushinada','David Martinez','Rebecca@cdpr.com','Morgan Blackhand','Valerie'])
df

# %% [markdown]
# Lấy ra mail của những người có trong danh sách trên

# %% [markdown]
# || Occupation code   | Occupation tittle| Level| Wage | Increase   |
# |:-|:------------------|:------------------|:-----|:-----|:-----------|
# | Israa@gmail.com| 11-1031| Legislators| detail| \$71,100  | 1.7%|
# |MartaMarisa@hotmail.com | 11-2000| Advertising, Marketing, Promotions, Public Relations, and Sales Managers | minor| \$152,320 | 0.4%|
# |HannahCona@yahoo.com| 11-2011| Advertising and Promotions Managers| detail| \$147,050 | 2.2%|
# | MartineAgatino@git.com | 11-2022| Sales Managers| detail  | \$150,530 | 0.4%|
# | Rebecca@cdpr.com| 11-2033| Fundraising Managers| detail  | \$124,450 | 1.3%|

# %% [markdown]
# Đọc thêm về biểu thức chính quy
#
# RegEx
# - https://www.w3schools.com/python/python_regex.asp

# %% [markdown]
# ### Truy vấn DataFrame (phần 4)
#
# - DataFrame.idxmax([axis, skipna, numeric_only]) : Trả về chỉ số vị trí của giá trị lớn nhất đầu tiên xuất hiện
#   - axis : Chọn trục lấy max
#   - skipna : Lựa chọn có bỏ qua giá trị NA hay không
#
# - DataFrame.idxmin([axis, skipna, numeric_only]) : Trả về chỉ số vị trí của giá trị lớn nhỏ đầu tiên xuất hiện
#   - axis : Chọn trục lấy min
#   - skipna : Lựa chọn có bỏ qua giá trị NA hay không

# %%
from sklearn.datasets import load_wine
df = load_wine(as_frame=True).data
df.head()
# Out:
#      alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols
# 0      14.23        1.71  2.43               15.6      127.0           2.80  \
# 1      13.20        1.78  2.14               11.2      100.0           2.65
# 2      13.16        2.36  2.67               18.6      101.0           2.80
# 3      14.37        1.95  2.50               16.8      113.0           3.85
# 4      13.24        2.59  2.87               21.0      118.0           2.80
# ..       ...         ...   ...                ...        ...            ...
# 173    13.71        5.65  2.45               20.5       95.0           1.68
# 174    13.40        3.91  2.48               23.0      102.0           1.80
# 175    13.27        4.28  2.26               20.0      120.0           1.59
# 176    13.17        2.59  2.37               20.0      120.0           1.65
# 177    14.13        4.10  2.74               24.5       96.0           2.05
#
#      flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity   hue
# 0          3.06                  0.28             2.29             5.64  1.04  \
# 1          2.76                  0.26             1.28             4.38  1.05
# 2          3.24                  0.30             2.81             5.68  1.03
# 3          3.49                  0.24             2.18             7.80  0.86
# 4          2.69                  0.39             1.82             4.32  1.04
# ..          ...                   ...              ...              ...   ...
# 173        0.61                  0.52             1.06             7.70  0.64
# 174        0.75                  0.43             1.41             7.30  0.70
# 175        0.69                  0.43             1.35            10.20  0.59
# 176        0.68                  0.53             1.46             9.30  0.60
# 177        0.76                  0.56             1.35             9.20  0.61
#
#      od280/od315_of_diluted_wines  proline
# 0                            3.92   1065.0
# 1                            3.40   1050.0
# 2                            3.17   1185.0
# 3                            3.45   1480.0
# 4                            2.93    735.0
# ..                            ...      ...
# 173                          1.74    740.0
# 174                          1.56    750.0
# 175                          1.56    835.0
# 176                          1.62    840.0
# 177                          1.60    560.0
#
# [178 rows x 13 columns]

# %%
df.idxmax() # trả về giá trị lớn nhất của từng cột
# Out:
# alcohol                           8
# malic_acid                      123
# ash                             121
# alcalinity_of_ash                73
# magnesium                        95
# total_phenols                    52
# flavanoids                      121
# nonflavanoid_phenols            105
# proanthocyanins                 110
# color_intensity                 158
# hue                             115
# od280/od315_of_diluted_wines     22
# proline                          18
# dtype: int64

# %%
df.idxmax(axis = 'columns') # trả về giá trị lớn nhất của từng hàng
# Out:
# 0      proline
# 1      proline
# 2      proline
# 3      proline
# 4      proline
#         ...
# 173    proline
# 174    proline
# 175    proline
# 176    proline
# 177    proline
# Length: 178, dtype: object

# %%
exam_data = {'score': [12.5, 9, 16.5, np.nan, 9, 20, 14.5, np.nan, 8, 19],
'attempts': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1]}

df = pd.DataFrame(exam_data,index = ['Anastasia', 'Dima', 'Katherine', 'James', 'Emily', 'Michael', 'Matthew', 'Laura', 'Kevin', 'Jonas'])
df
# Out:
#            score  attempts
# Anastasia   12.5         1
# Dima         9.0         3
# Katherine   16.5         2
# James        NaN         3
# Emily        9.0         2
# Michael     20.0         3
# Matthew     14.5         1
# Laura        NaN         1
# Kevin        8.0         2
# Jonas       19.0         1

# %%
df.idxmax()
# Out:
# score       Michael
# attempts       Dima
# dtype: object

# %%
df.idxmax(skipna=False)
# Out:
# score        NaN
# attempts    Dima
# dtype: object

# %%
df.idxmax(skipna=True)
# Out:
# score       Michael
# attempts       Dima
# dtype: object

# %%
data = {'Toán':[9,8,8,10],'Văn':[8,6,7,9],'Lý':[7,6,4,8],'Hóa':[8,8,9,9],'Sinh':[8,8,7,9]}
df = pd.DataFrame(data,index = ['An','Bình','Cường','Diễm'])
df
# Out:
#        Toán  Văn  Lý  Hóa  Sinh
# An        9    8   7    8     8
# Bình      8    6   6    8     8
# Cường     8    7   4    9     7
# Diễm     10    9   8    9     9

# %% [markdown]
# - Tìm ra môn học giỏi nhất của từng bạn
# - Tìm ra bạn học giỏi nhất của từng môn
# - Tìm ra môn học kém nhất của từng bạn
# - Tìm ra bạn học kém nhất của từng môn

# %% [markdown]
# ### Truy vấn DataFrame(phần 5)
# - DataFrame.at_time(time) : Lựa chọn giá trị tại một thời điểm trong ngày
#
# - DataFrame.between_time(start_time, end_time) : Lựa chọn những giá trị nằm trong một khoảng thời gian trong ngày
#   - start_time : Thời gian bắt đầu khoảng
#   - end_time : Thời gian kết thúc khoảng
# - DataFrame.first(offset) : Lựa chọn khoảng thời gian đầu
#
# - DataFrame.last(offset) : Lựa chọn khoảng thời gian cuối

# %%
data = {
        'volumes_max' : [120.0, 123.0, 102.0, None, 111.0, None, 124.0],
        'volumes': [120.0, 130.0, 102.0, None, 111.0	,None , 124.0],
        'temperature' : [22.0, 23.0, 21.0, 36.0, None, 31.0, 25.0]}
df = pd.DataFrame(data,index = pd.to_datetime(['01/01/2022 12:00','02/01/2022 11:30','03/01/2022 13:00','04/01/2022 12:30','05/01/2022 11:30','06/01/2022 13:30','06/01/2022 14:30'],format='%d/%m/%Y %H:%M'))
df
# Out:
#                      volumes_max  volumes  temperature
# 2022-01-01 12:00:00        120.0    120.0         22.0
# 2022-01-02 11:30:00        123.0    130.0         23.0
# 2022-01-03 13:00:00        102.0    102.0         21.0
# 2022-01-04 12:30:00          NaN      NaN         36.0
# 2022-01-05 11:30:00        111.0    111.0          NaN
# 2022-01-06 13:30:00          NaN      NaN         31.0
# 2022-01-06 14:30:00        124.0    124.0         25.0

# %%
df.at_time('12:00')
# Out:
#                      volumes_max  volumes  temperature
# 2022-01-01 12:00:00        120.0    120.0         22.0

# %%
df.at_time('11:30:00')
# Out:
#                      volumes_max  volumes  temperature
# 2022-01-02 11:30:00        123.0    130.0         23.0
# 2022-01-05 11:30:00        111.0    111.0          NaN

# %%
df.at_time('12:30')
# Out:
#                      volumes_max  volumes  temperature
# 2022-01-04 12:30:00          NaN      NaN         36.0

# %%
df.at_time('11:30')
# Out:
#                      volumes_max  volumes  temperature
# 2022-01-02 11:30:00        123.0    130.0         23.0
# 2022-01-05 11:30:00        111.0    111.0          NaN

# %%
df.between_time('11:00','13:00')
# Out:
#                      volumes_max  volumes  temperature
# 2022-01-01 12:00:00        120.0    120.0         22.0
# 2022-01-02 11:30:00        123.0    130.0         23.0
# 2022-01-03 13:00:00        102.0    102.0         21.0
# 2022-01-04 12:30:00          NaN      NaN         36.0
# 2022-01-05 11:30:00        111.0    111.0          NaN

# %%
df.between_time('12:00','14:00')
# Out:
#                      volumes_max  volumes  temperature
# 2022-01-01 12:00:00        120.0    120.0         22.0
# 2022-01-03 13:00:00        102.0    102.0         21.0
# 2022-01-04 12:30:00          NaN      NaN         36.0
# 2022-01-06 13:30:00          NaN      NaN         31.0

# %%
df.first('2D')
# Out:
#                      volumes_max  volumes  temperature
# 2022-01-01 12:00:00        120.0    120.0         22.0
# 2022-01-02 11:30:00        123.0    130.0         23.0

# %%
df.last('3H')
# Out:
#                      volumes_max  volumes  temperature
# 2022-01-06 13:30:00          NaN      NaN         31.0
# 2022-01-06 14:30:00        124.0    124.0         25.0

# %%
df.first('1W')
# Out:
#                      volumes_max  volumes  temperature
# 2022-01-01 12:00:00        120.0    120.0         22.0
# 2022-01-02 11:30:00        123.0    130.0         23.0

# %%
air_quality = pd.read_csv("https://raw.githubusercontent.com/pandas-dev/pandas/main/doc/data/air_quality_no2.csv",index_col=0, parse_dates=True)
air_quality
# Out:
#                      station_antwerp  station_paris  station_london
# datetime
# 2019-05-07 02:00:00              NaN            NaN            23.0
# 2019-05-07 03:00:00             50.5           25.0            19.0
# 2019-05-07 04:00:00             45.0           27.7            19.0
# 2019-05-07 05:00:00              NaN           50.4            16.0
# 2019-05-07 06:00:00              NaN           61.9             NaN
# ...                              ...            ...             ...
# 2019-06-20 22:00:00              NaN           21.4             NaN
# 2019-06-20 23:00:00              NaN           24.9             NaN
# 2019-06-21 00:00:00              NaN           26.5             NaN
# 2019-06-21 01:00:00              NaN           21.8             NaN
# 2019-06-21 02:00:00              NaN           20.0             NaN
#
# [1035 rows x 3 columns]

# %% [markdown]
# - Lấy ra dữ liệu 3 ngày đầu tiên
# - Lấy ra dữ liệu 5 ngày cuối cùng
# - Lấy dữ liệu 1 tháng cuối cùng
# - Lấy dữ liệu 1 tháng dầu tiên
# - Lấy ra dữ liệu vào thời điểm 12 giờ trưa
# - Lấy ra dữ liệu vào thời điểm 12 giờ đêm
# - Lấy ra dữ liệu vào khoảng thời gian 8 giờ sáng đến 10 giờ sáng
# - Lẩy ra dữ liệu vào khoảng thời gian từ 4 giờ chiều đến 7 giờ chiều

# %% [markdown]
# ## Thay đổi giá trị theo điều kiện

# %% [markdown]
# - DataFrame.where(cond, other) : Thay đổi giá trị tại vị trí có logic là False
#
# - DataFrame.mask(cond, other) : Thay đổi giá trị tại vị trí có logic là True

# %%
data = {'Toán':[9,8,8,10],'Lý':[7,6,4,8],'Hóa':[0,0,0,1]}
df = pd.DataFrame(data,index = ['An','Bình','Cường','Diễm'])
df
# Out:
#        Toán  Lý  Hóa
# An        9   7    0
# Bình      8   6    0
# Cường     8   4    0
# Diễm     10   8    1

# %%
data = {'Toán':[9,8,8,10],'Lý':[7,6,4,8],'Hóa':[np.nan,0,0,1]}
df = pd.DataFrame(data,index = ['An','Bình','Cường','Diễm'])
df
# Out:
#        Toán  Lý  Hóa
# An        9   7  NaN
# Bình      8   6  0.0
# Cường     8   4  0.0
# Diễm     10   8  1.0

# %%
df.where(df!=8,-1) # chỗ nào có 8 thì chuyển thành -1
# Out:
#        Toán  Lý  Hóa
# An        9   7    0
# Bình     -1   6    0
# Cường    -1   4    0
# Diễm     10  -1    1

# %%
df.where(df['Hóa']==0,10) # chỗ nào 0 thì giữ nguyên, còn lại thì chuyển thành 10
# Out:
#        Toán  Lý  Hóa
# An        9   7    0
# Bình      8   6    0
# Cường     8   4    0
# Diễm     10  10   10

# %%
df[['Hóa']].where(df['Hóa']==0,10)
# Out:
#        Hóa
# An       0
# Bình     0
# Cường    0
# Diễm    10

# %%
df.mask(df == 8,5)
# Out:
#        Toán  Lý  Hóa
# An        9   7    0
# Bình      5   6    0
# Cường     5   4    0
# Diễm     10   5    1

# %%
df.mask(df == 1,2)
# Out:
#        Toán  Lý  Hóa
# An        9   7    0
# Bình      8   6    0
# Cường     8   4    0
# Diễm     10   8    2

# %% [markdown]
# ## Chạy vòng lặp

# %% [markdown]
# - DataFrame.\_\_iter\_\_() : Chạy theo tên cột
#
# - DataFrame.keys() : Lấy ra danh sách tên cột
#
# - DataFrame.items() : Chạy theo tên cột và dữ liệu cột
#
# - DataFrame.iterrows() : Chạy theo chỉ số dòng và dữ liệu dòng
#
# - DataFrame.itertuples() : Chạy theo DataFrame theo dòng mỗi dòng sẽ là một tuples được đánh tên

# %%
from sklearn.datasets import load_wine
df = load_wine(as_frame=True).data
df.head()
# Out:
#    alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols
# 0    14.23        1.71  2.43               15.6      127.0           2.80  \
# 1    13.20        1.78  2.14               11.2      100.0           2.65
# 2    13.16        2.36  2.67               18.6      101.0           2.80
# 3    14.37        1.95  2.50               16.8      113.0           3.85
# 4    13.24        2.59  2.87               21.0      118.0           2.80
#
#    flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity   hue
# 0        3.06                  0.28             2.29             5.64  1.04  \
# 1        2.76                  0.26             1.28             4.38  1.05
# 2        3.24                  0.30             2.81             5.68  1.03
# 3        3.49                  0.24             2.18             7.80  0.86
# 4        2.69                  0.39             1.82             4.32  1.04
#
#    od280/od315_of_diluted_wines  proline
# 0                          3.92   1065.0
# 1                          3.40   1050.0
# 2                          3.17   1185.0
# 3                          3.45   1480.0
# 4                          2.93    735.0

# %%
for i in df.__iter__():
  print(i)
# Out:
# alcohol
# malic_acid
# ash
# alcalinity_of_ash
# magnesium
# total_phenols
# flavanoids
# nonflavanoid_phenols
# proanthocyanins
# color_intensity
# hue
# od280/od315_of_diluted_wines
# proline

# %%
df.keys()
# Out:
# Index(['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'magnesium',
#        'total_phenols', 'flavanoids', 'nonflavanoid_phenols',
#        'proanthocyanins', 'color_intensity', 'hue',
#        'od280/od315_of_diluted_wines', 'proline'],
#       dtype='object')

# %%
df.keys()[0]
# Out:
# 'alcohol'

# %%
for label,content in  df.items():
  print(label)
  print(content)
  break

# Nếu không có break nó sẽ duyệt từ đầu đến cuối, vì có break ở đây nên khi nó chạy hết vòng đầu tiên và in ra thì gặp breck nên đã thoát vòng lặp tại label = 0
# Nếu muốn nó chạy tiêp thì chỉ cần thêm điều kiện vòng lặp tại if là okela
# Out:
# alcohol
# 0      14.23
# 1      13.20
# 2      13.16
# 3      14.37
# 4      13.24
#        ...
# 173    13.71
# 174    13.40
# 175    13.27
# 176    13.17
# 177    14.13
# Name: alcohol, Length: 178, dtype: float64

# %%
for index,row in df.iterrows():
  print('index:',index)
  print(row)
  break
# Out:
# index: 0
# alcohol                           14.23
# malic_acid                         1.71
# ash                                2.43
# alcalinity_of_ash                 15.60
# magnesium                        127.00
# total_phenols                      2.80
# flavanoids                         3.06
# nonflavanoid_phenols               0.28
# proanthocyanins                    2.29
# color_intensity                    5.64
# hue                                1.04
# od280/od315_of_diluted_wines       3.92
# proline                         1065.00
# Name: 0, dtype: float64
# index: 1
# alcohol                           13.20
# malic_acid                         1.78
# ash                                2.14
# alcalinity_of_ash                 11.20
# magnesium                        100.00
# total_phenols                      2.65
# flavanoids                         2.76
# nonflavanoid_phenols               0.26
# proanthocyanins                    1.28
# color_intensity                    4.38
# hue                                1.05
# od280/od315_of_diluted_wines       3.40
# proline                         1050.00
# Name: 1, dtype: float64
# index: 2
# alcohol                           13.16
# malic_acid                         2.36
# ash                                2.67
# alcalinity_of_ash                 18.60
# magnesium                        101.00
# total_phenols                      2.80
# flavanoids                         3.24
# nonflavanoid_phenols               0.30
# proanthocyanins                    2.81
# color_intensity                    5.68
# hue                                1.03
# od280/od315_of_diluted_wines       3.17
# proline                         1185.00
# Name: 2, dtype: float64

# %%
for i in df.itertuples():
  print(i)
  print(len(i))
  print(i[0])
  print(i[1])
  print(i.malic_acid)
  if i.Index ==2:
    break
# Out:
# Pandas(Index=0, alcohol=14.23, malic_acid=1.71, ash=2.43, alcalinity_of_ash=15.6, magnesium=127.0, total_phenols=2.8, flavanoids=3.06, nonflavanoid_phenols=0.28, proanthocyanins=2.29, color_intensity=5.64, hue=1.04, _12=3.92, proline=1065.0)
# 14
# 0
# 14.23
# 1.71
# Pandas(Index=1, alcohol=13.2, malic_acid=1.78, ash=2.14, alcalinity_of_ash=11.2, magnesium=100.0, total_phenols=2.65, flavanoids=2.76, nonflavanoid_phenols=0.26, proanthocyanins=1.28, color_intensity=4.38, hue=1.05, _12=3.4, proline=1050.0)
# 14
# 1
# 13.2
# 1.78
# Pandas(Index=2, alcohol=13.16, malic_acid=2.36, ash=2.67, alcalinity_of_ash=18.6, magnesium=101.0, total_phenols=2.8, flavanoids=3.24, nonflavanoid_phenols=0.3, proanthocyanins=2.81, color_intensity=5.68, hue=1.03, _12=3.17, proline=1185.0)
# 14
# 2
# 13.16
# 2.36

# %% [markdown]
# # Tài liệu tham khảo

# %% [markdown]
# https://pandas.pydata.org/docs/user_guide/indexing.html
#
# https://pandas.pydata.org/docs/reference/frame.html
#
# https://pandas.pydata.org/docs/user_guide/index.html
#
# https://pandas.pydata.org/docs/user_guide/io.html
#
# https://pandas.pydata.org/docs/user_guide/10min.html
#
# https://pandas.pydata.org/docs/reference/general_functions.html
#
# https://www.w3schools.com/python/python_datetime.asp
